# %% [markdown]
# # Numerical Physics Project
# # 1) Introduction
# We are looking at the Travelling Salesman Problem, which can be mathematically formulated as : \
# We have a set of $n$ cities, with $C_{i,j}$ being the distance between the city $i$ and the city $j$. The goal is to find the shortest path visiting every city exactly once and returning to the first city. We note $x_{i,t}$ a boolean variable, such that $x_{i,t}= 1$ if the $i$-th city is visited at timestep $t$, and  $x_{i,t}= 0$ otherwise.
# Thus, our goal is to find $x \in \{0, 1\}^{n^2}$ which minimizes the cost function :
# $$C_{\text{cost}}(x) = \sum_{0 \leq i,j<n} C_{i,j} \sum_t x_{i,t}x_{j, t+1}$$
# Since we can only visit a given city once, and we can only be at one city at a given time, we also have the following constraints :
# $$ \sum_{0\leq i <n } x_{i,t} = 1, \ \forall t \in [\![0, n-1]\!] $$
# $$\sum_{0\leq t <n } x_{i,t} = 1, \ \forall i \in [\![0, n-1]\!] $$

# %% [markdown]
# To enforce the constraints, we will use a penalization term in the cost function. Essentially, we will use the cost function $C =  C_{\text{cost}} + M\cdot C_{\text{penalty}}$ where :
# $$ C_{\text{penalty}} = \sum_{t}\left( 1 - \sum_{i} x_{i,t} \right)^2 + \sum_i \left(1 - \sum_t x_{i,t} \right)^2 $$
# And $M$ is a constant large enough for the penalization to be efficient. Notice there are constant terms in $C_{\text{penalty}}$, which we will remove in the hamiltonian, and notice that the total cost function is quadratic in the variables $x_{i,t}$, meaning we can map it onto a Ising Hamiltonian using the correspondance $x_{i,j} \leftrightarrow \frac12(1-Z_{i,t})$ where $Z_{i,t}$ is the pauli operator $Z$ acting on the qubit $i,t$.
# We note the cost Hamiltonian :
# $$ \hat{H}_C = \sum_{x \in  \{ 0, \ 1 \}^n } C(x) \ket{x}\bra{x}$$
# which is diagonal in the computationnal basis, and in terms of operators is equivalent to replacing every $x_{i,t}$ in $C(x)$ by $\frac12(1-Z_{i,t})$. We start the code with the imports for using MyQLM, and the initialization of the problem :

# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
from qat.lang.AQASM import Program
from qat.lang.AQASM import RX, X, H, Y, Z, PH, RZ
import time
from qat.opt import CombinatorialProblem
from qat.vsolve.ansatz import AnsatzFactory
from qat.pylinalg import PyLinalg
from qat.qpus import get_default_qpu
from qat.clinalg import CLinalg
from qat.plugins import ScipyMinimizePlugin
from qat.plugins import SPSAMinimizePlugin
from qat.core import Result
from qat.core.qpu import QPUHandler
from qat.core import Result
from qat.core.wrappers.result import aggregate_data

# %% [markdown]
# # 2) Initializing the problem

# %% [markdown]
# We initialize the problem itself and a constraint constant :

# %%
nb_cities = 3  # number of cities
nbLayers = 10 #number of optimization layers for QAOA
C = [[0, 1000, 1], [1, 0, 1000], [1000, 1, 0]]  # Cost matrix of the travel between two cities
constraint_constant = 2*np.max(C) * nb_cities # Constraint constant, this one works well

# %% [markdown]
# We will now draw the graph to make it easier to directly spot the optimal paths. \
# Since networkx used in conjunction with matplotlib does not allow correctly placed labels on curved edges, we will instead use the package graphviz for this. The installation being very tedious, we recommend you do not re-run the cell and leave it as is.

# %%
from graphviz import Digraph

G = Digraph()
# add nodes for each city
for i in range(nb_cities):
    G.node(str(i+1))
# add weighted edges
for (i,j), weight in np.ndenumerate(C):
    if weight != 0 :
        G.edge(str(i+1), str(j+1), str(weight))

G

# %% [markdown]
# Then we use MyQLM's functions to construct the hamiltonian corresponding to the cost function :

# %%
#Create a combinatorial problem
problem = CombinatorialProblem("TSP", False)
#initialize the boolean variables
var_array = problem.new_vars(nb_cities**2)
# Now we create the cost function as a boolean function

# This part corresponds to the actual cost function
for i in range(nb_cities):
    for j in range(nb_cities):
        for t in range(nb_cities - 1):
            problem.add_clause(
                var_array[i + nb_cities * t]
                & var_array[j + nb_cities * ((t + 1) % nb_cities)],
                C[i][j],
            )

# This part corresponds to the penalisation added to the cost function
# Here we developed the squared sums, simplified it and removed the constant terms
for t in range(nb_cities):
    for i in range(nb_cities):
        problem.add_clause(var_array[i + nb_cities * t], (-2) * constraint_constant)
        for i2 in range(nb_cities):
            if i2 != i:
                problem.add_clause(
                    var_array[i + nb_cities * t] & var_array[i2 + nb_cities * t],
                    2*constraint_constant,
                )
        
        for t2 in range(nb_cities):
            if t2 != t:
                problem.add_clause(
                    var_array[i + nb_cities * t] & var_array[i + nb_cities * t2],
                    2*constraint_constant,
                )

# %% [markdown]
# Note that with this Hamiltonian, the lowest eigenvalue is $-35998$, we thus want to converge towards this value.

# %% [markdown]
# # 3) Using the Quantum Approximate Optimization Algorithm

# %% [markdown]
# Now that our cost function has been created, we use the qaoa_ansatz method to create our job, which is a runable parametrized QAOA circuit, corresponding to preparing the state :
# $$\ket{\Phi(\vec{\gamma},\vec{\beta} )}=  \prod_1^p e^{-i\beta_i \hat{H}_B} e^{-i\gamma_i \hat{H}_C} \ket{+}. $$
# Where $\hat{H}_B = \sum_1^n X_i $ où $X_i$ and $\ket{+} = \left( \frac{\ket{0}+\ket{1}}{\sqrt{2}} \right) \otimes^n$

# %%
def run_qaoa(nb_layers):
    ansatz = problem.qaoa_ansatz(nb_layers)
    # initialize the optimizer
    # We chose the BFGS method because it is often regarded as the fastest optimization method for problems like this
    optimize = ScipyMinimizePlugin(
        method="BFGS", tol=1e-5, options={"maxiter": 10000}, x0 = [0.1]*(nb_layers*(nb_cities**2+1))
)  
    # We create a stack : the optimizer will feed jobs to the bottom part (the qpu) and optimize their parameters
    # We use the Broyden–Fletcher–Goldfarb–Shanno algorithm for the optimisation  as it usually works very well
    qpu = CLinalg()
    stack = (
        optimize | qpu
    )  
    result = stack.submit(ansatz)  # result
    print("energy : ", result.value)
    energy=result.value
    # we get the optimal parameters from the result and bind the variables of the circuit
    circuit = ansatz.circuit.bind_variables(
        result.parameter_map
    ) 
    job = circuit.to_job(
        nbshots=1000
    )  # a second job allowing us to know to what state the optimized parameters correspond 
    qpu = CLinalg()
    result = qpu.submit(job)  # result
    # for each state in the result we print its probability
    for sample in result:
        print("State %s amplitude %s" % (sample.state, sample.probability))
    # we then have to choose the most probable one
    return(energy)

# %%
nb_layers=[]
energy_list=[]
for i in range(1,10):
    energy=run_qaoa(i)
    nb_layers.append(i)
    energy_list.append(energy)
# Out:
# energy :  21569.86183843592
# State |000000000> amplitude 0.002
# State |000000001> amplitude 0.002
# State |000000010> amplitude 0.001
# State |000000100> amplitude 0.003
# State |000000111> amplitude 0.001
# State |000001000> amplitude 0.002
# State |000001001> amplitude 0.001
# State |000001010> amplitude 0.004
# State |000001011> amplitude 0.001
# State |000001100> amplitude 0.002
# State |000001101> amplitude 0.001
# State |000001110> amplitude 0.006
# State |000001111> amplitude 0.002
# State |000010000> amplitude 0.003
# State |000010001> amplitude 0.001
# State |000010011> amplitude 0.001
# State |000010101> amplitude 0.006
# State |000011000> amplitude 0.001
# State |000011001> amplitude 0.002
# State |000011010> amplitude 0.003
# State |000011011> amplitude 0.002
# State |000011100> amplitude 0.003
# State |000011101> amplitude 0.001
# State |000011111> amplitude 0.002
# State |000100001> amplitude 0.002
# State |000100010> amplitude 0.001
# State |000100011> amplitude 0.006
# State |000100110> amplitude 0.003
# State |000101000> amplitude 0.003
# State |000101001> amplitude 0.001
# State |000101010> amplitude 0.013
# State |000101101> amplitude 0.002
# State |000101110> amplitude 0.002
# State |000101111> amplitude 0.002
# State |000110000> amplitude 0.001
# State |000110001> amplitude 0.01
# State |000110011> amplitude 0.002
# State |000110100> amplitude 0.001
# State |000110111> amplitude 0.001
# State |000111000> amplitude 0.002
# State |000111101> amplitude 0.003
# State |000111110> amplitude 0.001
# State |000111111> amplitude 0.002
# State |001000000> amplitude 0.004
# State |001000001> amplitude 0.002
# State |001000010> amplitude 0.006
# State |001000101> amplitude 0.001
# State |001001010> amplitude 0.001
# State |001001011> amplitude 0.001
# State |001001100> amplitude 0.002
# State |001001101> amplitude 0.001
# State |001001110> amplitude 0.002
# State |001001111> amplitude 0.001
# State |001010000> amplitude 0.004
# State |001010011> amplitude 0.002
# State |001010100> amplitude 0.014
# State |001010101> amplitude 0.003
# State |001010110> amplitude 0.001
# State |001011001> amplitude 0.003
# State |001011100> amplitude 0.015
# State |001011101> amplitude 0.001
# State |001011110> amplitude 0.001
# State |001100000> amplitude 0.001
# State |001100010> amplitude 0.039
# State |001100011> amplitude 0.002
# State |001100100> amplitude 0.003
# State |001100111> amplitude 0.002
# State |001101001> amplitude 0.002
# State |001101010> amplitude 0.007
# State |001101011> amplitude 0.003
# State |001101100> amplitude 0.002
# State |001101101> amplitude 0.001
# State |001101110> amplitude 0.004
# State |001101111> amplitude 0.004
# State |001110000> amplitude 0.004
# State |001110001> amplitude 0.033
# State |001110010> amplitude 0.005
# State |001110011> amplitude 0.002
# State |001110100> amplitude 0.008
# State |001110101> amplitude 0.004
# State |001110110> amplitude 0.001
# State |001110111> amplitude 0.002
# State |001111001> amplitude 0.002
# State |001111011> amplitude 0.003
# State |001111100> amplitude 0.001
# State |001111110> amplitude 0.001
# State |010000000> amplitude 0.006
# State |010000001> amplitude 0.002
# State |010000010> amplitude 0.002
# State |010000100> amplitude 0.007
# State |010000101> amplitude 0.001
# State |010000111> amplitude 0.001
# State |010001000> amplitude 0.002
# State |010001001> amplitude 0.002
# State |010001100> amplitude 0.046
# State |010001111> amplitude 0.002
# State |010010001> amplitude 0.004
# State |010010011> amplitude 0.001
# State |010010101> amplitude 0.001
# State |010010110> amplitude 0.001
# State |010011001> amplitude 0.001
# State |010011010> amplitude 0.001
# State |010011011> amplitude 0.001
# State |010011100> amplitude 0.002
# State |010011101> amplitude 0.017
# State |010011110> amplitude 0.005
# State |010011111> amplitude 0.002
# State |010100000> amplitude 0.001
# State |010100001> amplitude 0.012
# State |010100011> amplitude 0.005
# State |010100110> amplitude 0.002
# State |010101000> amplitude 0.011
# State |010101001> amplitude 0.012
# State |010101010> amplitude 0.027
# State |010101011> amplitude 0.003
# State |010101100> amplitude 0.007
# State |010101101> amplitude 0.005
# State |010101110> amplitude 0.004
# State |010101111> amplitude 0.003
# State |010110000> amplitude 0.001
# State |010110001> amplitude 0.003
# State |010110010> amplitude 0.002
# State |010110011> amplitude 0.002
# State |010110111> amplitude 0.001
# State |010111001> amplitude 0.001
# State |010111110> amplitude 0.002
# State |011000001> amplitude 0.002
# State |011000011> amplitude 0.001
# State |011000101> amplitude 0.002
# State |011001000> amplitude 0.001
# State |011001001> amplitude 0.003
# State |011001010> amplitude 0.001
# State |011001101> amplitude 0.006
# State |011001110> amplitude 0.001
# State |011011000> amplitude 0.001
# State |011011001> amplitude 0.001
# State |011011010> amplitude 0.001
# State |011011100> amplitude 0.004
# State |011011101> amplitude 0.002
# State |011100000> amplitude 0.005
# State |011100001> amplitude 0.002
# State |011100010> amplitude 0.006
# State |011100100> amplitude 0.003
# State |011100110> amplitude 0.002
# State |011100111> amplitude 0.001
# State |011101000> amplitude 0.001
# State |011101010> amplitude 0.003
# State |011101100> amplitude 0.008
# State |011101110> amplitude 0.001
# State |011101111> amplitude 0.001
# State |011110000> amplitude 0.001
# State |011110001> amplitude 0.005
# State |011110010> amplitude 0.003
# State |011110011> amplitude 0.001
# State |011110110> amplitude 0.001
# State |011110111> amplitude 0.001
# State |011111000> amplitude 0.001
# State |011111010> amplitude 0.005
# State |011111100> amplitude 0.001
# State |011111101> amplitude 0.001
# State |011111110> amplitude 0.002
# State |011111111> amplitude 0.001
# State |100000000> amplitude 0.001
# State |100000001> amplitude 0.005
# State |100000010> amplitude 0.002
# State |100000100> amplitude 0.001
# State |100000111> amplitude 0.001
# State |100001000> amplitude 0.003
# State |100001001> amplitude 0.002
# State |100001010> amplitude 0.007
# State |100001101> amplitude 0.001
# State |100001110> amplitude 0.003
# State |100010000> amplitude 0.002
# State |100010001> amplitude 0.032
# State |100010010> amplitude 0.004
# State |100010100> amplitude 0.001
# State |100010101> amplitude 0.001
# State |100011000> amplitude 0.005
# State |100011001> amplitude 0.006
# State |100011010> amplitude 0.011
# State |100011011> amplitude 0.001
# State |100011100> amplitude 0.037
# State |100011101> amplitude 0.003
# State |100011110> amplitude 0.002
# State |100011111> amplitude 0.002
# State |100100010> amplitude 0.002
# State |100100011> amplitude 0.003
# State |100100101> amplitude 0.001
# State |100100110> amplitude 0.001
# State |100101010> amplitude 0.005
# State |100101100> amplitude 0.003
# State |100101110> amplitude 0.002
# State |100110000> amplitude 0.001
# State |100110001> amplitude 0.003
# State |100110010> amplitude 0.001
# State |100110011> amplitude 0.014
# State |100110101> amplitude 0.01
# State |100110111> amplitude 0.001
# State |100111010> amplitude 0.002
# State |100111011> amplitude 0.002
# State |100111100> amplitude 0.001
# State |100111101> amplitude 0.006
# State |100111110> amplitude 0.001
# State |100111111> amplitude 0.001
# State |101000010> amplitude 0.001
# State |101000110> amplitude 0.001
# State |101001011> amplitude 0.001
# State |101010000> amplitude 0.008
# State |101010001> amplitude 0.001
# State |101010010> amplitude 0.001
# State |101010011> amplitude 0.003
# State |101010100> amplitude 0.006
# State |101011001> amplitude 0.004
# State |101011011> amplitude 0.001
# State |101011100> amplitude 0.002
# State |101011111> amplitude 0.002
# State |101100000> amplitude 0.003
# State |101100001> amplitude 0.005
# State |101100011> amplitude 0.001
# State |101100100> amplitude 0.002
# State |101100101> amplitude 0.001
# State |101100110> amplitude 0.001
# State |101101010> amplitude 0.005
# State |101101011> amplitude 0.001
# State |101101100> amplitude 0.001
# State |101101101> amplitude 0.002
# State |101101111> amplitude 0.001
# State |101110000> amplitude 0.001
# State |101110010> amplitude 0.007
# State |101110011> amplitude 0.003
# State |101110101> amplitude 0.001
# State |101110111> amplitude 0.001
# State |101111000> amplitude 0.001
# State |101111001> amplitude 0.005
# State |101111010> amplitude 0.002
# State |101111011> amplitude 0.001
# State |101111110> amplitude 0.002
# State |101111111> amplitude 0.002
# State |110000010> amplitude 0.001
# State |110000100> amplitude 0.001
# State |110001000> amplitude 0.007
# State |110001001> amplitude 0.002
# State |110001010> amplitude 0.003
# State |110001100> amplitude 0.002
# State |110010000> amplitude 0.004
# State |110010011> amplitude 0.002
# State |110010111> amplitude 0.001
# State |110011001> amplitude 0.011
# State |110011010> amplitude 0.002
# State |110011011> amplitude 0.001
# State |110011100> amplitude 0.001
# State |110011101> amplitude 0.006
# State |110011110> amplitude 0.001
# State |110100100> amplitude 0.001
# State |110100111> amplitude 0.001
# State |110101010> amplitude 0.001
# State |110101011> amplitude 0.001
# State |110101100> amplitude 0.001
# State |110101101> amplitude 0.001
# State |110101110> amplitude 0.001
# State |110110001> amplitude 0.002
# State |110110010> amplitude 0.001
# State |110110100> amplitude 0.001
# State |110110110> amplitude 0.005
# State |110111001> amplitude 0.003
# State |110111011> amplitude 0.002
# State |110111100> amplitude 0.004
# State |110111101> amplitude 0.001
# State |111000001> amplitude 0.001
# State |111000010> amplitude 0.001
# State |111000100> amplitude 0.001
# State |111001000> amplitude 0.001
# State |111001001> amplitude 0.001
# State |111001100> amplitude 0.001
# State |111001101> amplitude 0.001
# State |111001110> amplitude 0.001
# State |111010001> amplitude 0.002
# State |111010010> amplitude 0.002
# State |111011000> amplitude 0.001
# State |111011001> amplitude 0.004
# State |111011010> amplitude 0.002
# State |111011100> amplitude 0.004
# State |111011110> amplitude 0.001
# State |111100010> amplitude 0.002
# State |111100011> amplitude 0.001
# State |111100100> amplitude 0.001
# State |111101000> amplitude 0.003
# State |111101010> amplitude 0.002
# State |111101011> amplitude 0.001
# State |111101100> amplitude 0.002
# State |111101111> amplitude 0.002
# State |111110000> amplitude 0.003
# State |111110001> amplitude 0.002
# State |111110100> amplitude 0.002
# State |111110101> amplitude 0.001
# State |111110110> amplitude 0.001
# State |111111000> amplitude 0.003
# State |111111111> amplitude 0.001
# energy :  -12159.408683254776
# State |000000000> amplitude 0.004
# State |000000001> amplitude 0.003
# State |000000010> amplitude 0.004
# State |000000011> amplitude 0.001
# State |000000100> amplitude 0.002
# State |000000101> amplitude 0.001
# State |000001000> amplitude 0.005
# State |000001001> amplitude 0.001
# State |000001010> amplitude 0.007
# State |000001100> amplitude 0.014
# State |000001101> amplitude 0.001
# State |000001110> amplitude 0.004
# State |000010000> amplitude 0.003
# State |000010001> amplitude 0.016
# State |000010100> amplitude 0.005
# State |000010101> amplitude 0.007
# State |000011000> amplitude 0.002
# State |000011011> amplitude 0.001
# State |000011100> amplitude 0.004
# State |000011101> amplitude 0.001
# State |000011110> amplitude 0.003
# State |000100000> amplitude 0.007
# State |000100001> amplitude 0.011
# State |000100010> amplitude 0.014
# State |000100011> amplitude 0.002
# State |000100111> amplitude 0.001
# State |000101000> amplitude 0.002
# State |000101010> amplitude 0.002
# State |000101011> amplitude 0.001
# State |000101110> amplitude 0.003
# State |000110001> amplitude 0.009
# State |000110010> amplitude 0.001
# State |000110011> amplitude 0.001
# State |000110101> amplitude 0.002
# State |000110110> amplitude 0.001
# State |000111000> amplitude 0.001
# State |000111010> amplitude 0.001
# State |000111100> amplitude 0.001
# State |000111110> amplitude 0.001
# State |001000000> amplitude 0.003
# State |001000001> amplitude 0.001
# State |001000010> amplitude 0.016
# State |001000011> amplitude 0.001
# State |001000100> amplitude 0.004
# State |001000101> amplitude 0.001
# State |001000110> amplitude 0.005
# State |001001000> amplitude 0.001
# State |001001010> amplitude 0.003
# State |001001100> amplitude 0.004
# State |001001110> amplitude 0.002
# State |001001111> amplitude 0.001
# State |001010000> amplitude 0.001
# State |001010001> amplitude 0.006
# State |001010010> amplitude 0.004
# State |001010100> amplitude 0.02
# State |001010101> amplitude 0.002
# State |001010110> amplitude 0.005
# State |001011100> amplitude 0.003
# State |001011101> amplitude 0.002
# State |001100000> amplitude 0.019
# State |001100001> amplitude 0.007
# State |001100010> amplitude 0.093
# State |001100011> amplitude 0.007
# State |001100100> amplitude 0.004
# State |001100110> amplitude 0.001
# State |001101001> amplitude 0.001
# State |001101010> amplitude 0.003
# State |001101100> amplitude 0.005
# State |001101110> amplitude 0.003
# State |001101111> amplitude 0.001
# State |001110000> amplitude 0.004
# State |001110001> amplitude 0.006
# State |001110010> amplitude 0.003
# State |001110100> amplitude 0.002
# State |001110101> amplitude 0.003
# State |001111010> amplitude 0.002
# State |001111100> amplitude 0.001
# State |001111101> amplitude 0.001
# State |010000000> amplitude 0.001
# State |010000001> amplitude 0.006
# State |010000100> amplitude 0.029
# State |010000101> amplitude 0.002
# State |010001000> amplitude 0.014
# State |010001001> amplitude 0.003
# State |010001010> amplitude 0.007
# State |010001100> amplitude 0.085
# State |010001110> amplitude 0.005
# State |010010000> amplitude 0.001
# State |010010001> amplitude 0.007
# State |010010100> amplitude 0.004
# State |010011001> amplitude 0.002
# State |010011101> amplitude 0.002
# State |010100000> amplitude 0.004
# State |010100001> amplitude 0.026
# State |010100010> amplitude 0.008
# State |010100011> amplitude 0.001
# State |010100100> amplitude 0.009
# State |010100101> amplitude 0.004
# State |010101000> amplitude 0.005
# State |010101001> amplitude 0.001
# State |010101010> amplitude 0.011
# State |010101100> amplitude 0.003
# State |010101110> amplitude 0.002
# State |010110001> amplitude 0.002
# State |010110011> amplitude 0.001
# State |010110101> amplitude 0.001
# State |010111001> amplitude 0.001
# State |010111010> amplitude 0.002
# State |011000000> amplitude 0.001
# State |011000100> amplitude 0.005
# State |011000110> amplitude 0.001
# State |011001100> amplitude 0.001
# State |011001110> amplitude 0.001
# State |011010100> amplitude 0.003
# State |011011001> amplitude 0.001
# State |011100000> amplitude 0.006
# State |011100001> amplitude 0.001
# State |011100010> amplitude 0.005
# State |011100100> amplitude 0.001
# State |011100101> amplitude 0.001
# State |011101000> amplitude 0.001
# State |011101001> amplitude 0.001
# State |011101010> amplitude 0.001
# State |011101100> amplitude 0.006
# State |011110001> amplitude 0.001
# State |011111000> amplitude 0.002
# State |011111101> amplitude 0.001
# State |100000001> amplitude 0.031
# State |100000010> amplitude 0.006
# State |100001000> amplitude 0.007
# State |100001001> amplitude 0.005
# State |100001010> amplitude 0.021
# State |100001011> amplitude 0.001
# State |100001100> amplitude 0.003
# State |100001110> amplitude 0.002
# State |100010000> amplitude 0.017
# State |100010001> amplitude 0.068
# State |100010010> amplitude 0.011
# State |100010100> amplitude 0.002
# State |100010101> amplitude 0.004
# State |100010110> amplitude 0.001
# State |100011000> amplitude 0.004
# State |100011001> amplitude 0.004
# State |100011010> amplitude 0.001
# State |100011100> amplitude 0.006
# State |100011110> amplitude 0.001
# State |100100001> amplitude 0.009
# State |100100010> amplitude 0.005
# State |100100011> amplitude 0.002
# State |100100101> amplitude 0.001
# State |100101010> amplitude 0.002
# State |100101011> amplitude 0.001
# State |100101100> amplitude 0.002
# State |100101110> amplitude 0.002
# State |100110001> amplitude 0.001
# State |100110010> amplitude 0.002
# State |100110011> amplitude 0.006
# State |100110100> amplitude 0.001
# State |100110111> amplitude 0.001
# State |100111000> amplitude 0.001
# State |100111011> amplitude 0.001
# State |100111101> amplitude 0.001
# State |100111110> amplitude 0.001
# State |100111111> amplitude 0.001
# State |101001001> amplitude 0.001
# State |101001010> amplitude 0.001
# State |101010000> amplitude 0.006
# State |101010001> amplitude 0.002
# State |101010011> amplitude 0.001
# State |101010100> amplitude 0.001
# State |101011000> amplitude 0.001
# State |101011010> amplitude 0.002
# State |101100010> amplitude 0.001
# State |101110000> amplitude 0.002
# State |101110001> amplitude 0.001
# State |101110010> amplitude 0.006
# State |101111011> amplitude 0.001
# State |110000000> amplitude 0.001
# State |110000001> amplitude 0.004
# State |110000011> amplitude 0.001
# State |110000111> amplitude 0.001
# State |110001000> amplitude 0.006
# State |110001001> amplitude 0.002
# State |110001010> amplitude 0.003
# State |110001100> amplitude 0.003
# State |110001101> amplitude 0.002
# State |110001110> amplitude 0.001
# State |110010011> amplitude 0.003
# State |110011000> amplitude 0.003
# State |110011001> amplitude 0.003
# State |110011010> amplitude 0.001
# State |110011100> amplitude 0.003
# State |110100110> amplitude 0.001
# State |110101001> amplitude 0.001
# State |110101010> amplitude 0.001
# State |110101100> amplitude 0.001
# State |110101110> amplitude 0.001
# State |110111101> amplitude 0.001
# State |111001100> amplitude 0.001
# State |111011001> amplitude 0.001
# State |111100100> amplitude 0.001
# State |111111000> amplitude 0.003
# energy :  -12542.723557900943
# State |000000000> amplitude 0.064
# State |000000001> amplitude 0.028
# State |000000010> amplitude 0.015
# State |000000011> amplitude 0.001
# State |000000100> amplitude 0.027
# State |000000101> amplitude 0.004
# State |000001000> amplitude 0.009
# State |000001010> amplitude 0.024
# State |000001100> amplitude 0.001
# State |000001110> amplitude 0.006
# State |000010000> amplitude 0.012
# State |000010001> amplitude 0.003
# State |000010100> amplitude 0.022
# State |000010101> amplitude 0.007
# State |000011001> amplitude 0.001
# State |000011010> amplitude 0.001
# State |000011100> amplitude 0.001
# State |000100000> amplitude 0.015
# State |000100001> amplitude 0.032
# State |000100010> amplitude 0.003
# State |000100100> amplitude 0.001
# State |000100101> amplitude 0.001
# State |000101000> amplitude 0.001
# State |000101010> amplitude 0.001
# State |000101011> amplitude 0.002
# State |000110001> amplitude 0.001
# State |000110101> amplitude 0.002
# State |000111111> amplitude 0.001
# State |001000000> amplitude 0.021
# State |001000001> amplitude 0.001
# State |001000010> amplitude 0.045
# State |001000100> amplitude 0.014
# State |001000110> amplitude 0.006
# State |001001010> amplitude 0.01
# State |001001011> amplitude 0.002
# State |001001101> amplitude 0.001
# State |001010000> amplitude 0.023
# State |001010010> amplitude 0.012
# State |001010100> amplitude 0.053
# State |001010110> amplitude 0.01
# State |001010111> amplitude 0.003
# State |001011000> amplitude 0.001
# State |001011010> amplitude 0.003
# State |001011011> amplitude 0.001
# State |001011110> amplitude 0.001
# State |001100000> amplitude 0.003
# State |001100010> amplitude 0.006
# State |001101000> amplitude 0.001
# State |001101010> amplitude 0.003
# State |001110000> amplitude 0.003
# State |001110001> amplitude 0.002
# State |001110010> amplitude 0.001
# State |001110011> amplitude 0.001
# State |001110101> amplitude 0.001
# State |001110110> amplitude 0.002
# State |001111110> amplitude 0.001
# State |010000000> amplitude 0.025
# State |010000001> amplitude 0.009
# State |010000010> amplitude 0.001
# State |010000100> amplitude 0.029
# State |010000101> amplitude 0.002
# State |010001011> amplitude 0.001
# State |010001100> amplitude 0.005
# State |010001101> amplitude 0.001
# State |010010011> amplitude 0.001
# State |010010100> amplitude 0.011
# State |010010101> amplitude 0.002
# State |010011100> amplitude 0.001
# State |010011101> amplitude 0.001
# State |010011111> amplitude 0.001
# State |010100000> amplitude 0.019
# State |010100001> amplitude 0.048
# State |010100010> amplitude 0.001
# State |010100100> amplitude 0.008
# State |010100101> amplitude 0.01
# State |010101000> amplitude 0.003
# State |010101010> amplitude 0.002
# State |010101011> amplitude 0.001
# State |010101100> amplitude 0.002
# State |010101101> amplitude 0.003
# State |010110011> amplitude 0.001
# State |010110101> amplitude 0.001
# State |010110110> amplitude 0.001
# State |010111101> amplitude 0.001
# State |011000000> amplitude 0.002
# State |011000010> amplitude 0.003
# State |011000100> amplitude 0.001
# State |011000110> amplitude 0.003
# State |011001001> amplitude 0.001
# State |011001100> amplitude 0.001
# State |011010100> amplitude 0.003
# State |011011100> amplitude 0.002
# State |011100000> amplitude 0.003
# State |011100100> amplitude 0.003
# State |011110000> amplitude 0.002
# State |011110100> amplitude 0.001
# State |011111101> amplitude 0.001
# State |100000000> amplitude 0.025
# State |100000001> amplitude 0.028
# State |100000010> amplitude 0.01
# State |100000011> amplitude 0.002
# State |100000100> amplitude 0.001
# State |100000111> amplitude 0.001
# State |100001000> amplitude 0.025
# State |100001001> amplitude 0.017
# State |100001010> amplitude 0.05
# State |100001011> amplitude 0.003
# State |100001111> amplitude 0.001
# State |100010001> amplitude 0.003
# State |100010011> amplitude 0.002
# State |100010100> amplitude 0.001
# State |100010101> amplitude 0.001
# State |100011000> amplitude 0.003
# State |100011001> amplitude 0.001
# State |100011011> amplitude 0.005
# State |100011100> amplitude 0.003
# State |100011110> amplitude 0.001
# State |100100001> amplitude 0.01
# State |100100101> amplitude 0.002
# State |100100110> amplitude 0.001
# State |100101001> amplitude 0.001
# State |100110100> amplitude 0.001
# State |100111000> amplitude 0.001
# State |100111001> amplitude 0.001
# State |101000001> amplitude 0.001
# State |101000010> amplitude 0.003
# State |101000011> amplitude 0.001
# State |101001010> amplitude 0.006
# State |101001100> amplitude 0.001
# State |101010000> amplitude 0.003
# State |101010011> amplitude 0.001
# State |101011000> amplitude 0.004
# State |101011010> amplitude 0.004
# State |101011100> amplitude 0.002
# State |101100000> amplitude 0.001
# State |101100010> amplitude 0.002
# State |101100110> amplitude 0.001
# State |101101010> amplitude 0.004
# State |110000000> amplitude 0.002
# State |110000001> amplitude 0.006
# State |110000100> amplitude 0.001
# State |110000110> amplitude 0.001
# State |110001000> amplitude 0.003
# State |110010000> amplitude 0.001
# State |110010001> amplitude 0.002
# State |110011101> amplitude 0.001
# State |110100001> amplitude 0.004
# State |110100010> amplitude 0.002
# State |110101011> amplitude 0.001
# State |110110001> amplitude 0.001
# State |110111100> amplitude 0.001
# State |111000000> amplitude 0.001
# State |111001001> amplitude 0.001
# State |111001010> amplitude 0.001
# State |111100100> amplitude 0.001
# State |111101001> amplitude 0.001
# State |111111000> amplitude 0.001
# energy :  -5545.072149005806
# State |000000000> amplitude 0.007
# State |000000010> amplitude 0.001
# State |000000011> amplitude 0.003
# State |000000100> amplitude 0.001
# State |000000101> amplitude 0.001
# State |000000110> amplitude 0.004
# State |000001000> amplitude 0.017
# State |000001001> amplitude 0.001
# State |000001010> amplitude 0.005
# State |000001011> amplitude 0.001
# State |000001100> amplitude 0.032
# State |000001110> amplitude 0.003
# State |000010000> amplitude 0.022
# State |000010001> amplitude 0.029
# State |000010010> amplitude 0.001
# State |000010011> amplitude 0.002
# State |000010100> amplitude 0.008
# State |000010101> amplitude 0.003
# State |000011000> amplitude 0.001
# State |000011001> amplitude 0.001
# State |000011010> amplitude 0.001
# State |000011100> amplitude 0.002
# State |000011101> amplitude 0.002
# State |000100000> amplitude 0.02
# State |000100001> amplitude 0.011
# State |000100010> amplitude 0.024
# State |000100011> amplitude 0.003
# State |000100100> amplitude 0.001
# State |000100101> amplitude 0.001
# State |000100110> amplitude 0.002
# State |000101000> amplitude 0.001
# State |000101001> amplitude 0.001
# State |000101010> amplitude 0.002
# State |000101011> amplitude 0.001
# State |000101100> amplitude 0.004
# State |000101110> amplitude 0.003
# State |000110000> amplitude 0.001
# State |000110001> amplitude 0.006
# State |000110010> amplitude 0.001
# State |000110100> amplitude 0.002
# State |000110101> amplitude 0.001
# State |000111000> amplitude 0.004
# State |000111001> amplitude 0.003
# State |000111100> amplitude 0.001
# State |000111111> amplitude 0.001
# State |001000001> amplitude 0.008
# State |001000010> amplitude 0.02
# State |001000100> amplitude 0.005
# State |001001000> amplitude 0.001
# State |001001010> amplitude 0.001
# State |001001011> amplitude 0.001
# State |001001100> amplitude 0.009
# State |001001110> amplitude 0.004
# State |001010000> amplitude 0.008
# State |001010001> amplitude 0.001
# State |001010010> amplitude 0.001
# State |001010011> amplitude 0.001
# State |001010100> amplitude 0.011
# State |001011000> amplitude 0.003
# State |001011100> amplitude 0.002
# State |001011101> amplitude 0.001
# State |001100000> amplitude 0.029
# State |001100010> amplitude 0.072
# State |001100100> amplitude 0.005
# State |001101000> amplitude 0.001
# State |001101010> amplitude 0.001
# State |001101100> amplitude 0.005
# State |001101110> amplitude 0.002
# State |001101111> amplitude 0.001
# State |001110000> amplitude 0.005
# State |001110001> amplitude 0.012
# State |001110011> amplitude 0.001
# State |001110100> amplitude 0.004
# State |001110110> amplitude 0.002
# State |001111010> amplitude 0.004
# State |010000000> amplitude 0.001
# State |010000001> amplitude 0.006
# State |010000010> amplitude 0.005
# State |010000100> amplitude 0.015
# State |010000101> amplitude 0.001
# State |010001000> amplitude 0.011
# State |010001001> amplitude 0.005
# State |010001010> amplitude 0.001
# State |010001100> amplitude 0.058
# State |010010000> amplitude 0.002
# State |010010001> amplitude 0.008
# State |010010100> amplitude 0.004
# State |010010101> amplitude 0.004
# State |010010111> amplitude 0.002
# State |010011000> amplitude 0.002
# State |010011001> amplitude 0.001
# State |010100000> amplitude 0.009
# State |010100001> amplitude 0.01
# State |010100010> amplitude 0.003
# State |010100011> amplitude 0.001
# State |010100100> amplitude 0.001
# State |010100110> amplitude 0.003
# State |010101000> amplitude 0.009
# State |010101010> amplitude 0.01
# State |010101011> amplitude 0.001
# State |010101100> amplitude 0.001
# State |010110000> amplitude 0.003
# State |010110001> amplitude 0.002
# State |010110010> amplitude 0.002
# State |010110101> amplitude 0.001
# State |010110111> amplitude 0.001
# State |010111000> amplitude 0.001
# State |010111011> amplitude 0.001
# State |010111100> amplitude 0.002
# State |011000000> amplitude 0.001
# State |011000010> amplitude 0.001
# State |011000011> amplitude 0.004
# State |011000100> amplitude 0.002
# State |011000110> amplitude 0.003
# State |011001010> amplitude 0.002
# State |011001110> amplitude 0.001
# State |011010111> amplitude 0.002
# State |011011100> amplitude 0.001
# State |011011101> amplitude 0.001
# State |011100000> amplitude 0.002
# State |011100001> amplitude 0.002
# State |011100100> amplitude 0.005
# State |011101000> amplitude 0.006
# State |011101010> amplitude 0.002
# State |011101100> amplitude 0.001
# State |011101110> amplitude 0.001
# State |011111101> amplitude 0.001
# State |100000001> amplitude 0.021
# State |100000010> amplitude 0.006
# State |100000011> amplitude 0.001
# State |100000100> amplitude 0.003
# State |100001000> amplitude 0.009
# State |100001001> amplitude 0.001
# State |100001010> amplitude 0.006
# State |100001100> amplitude 0.003
# State |100001101> amplitude 0.003
# State |100001110> amplitude 0.001
# State |100010000> amplitude 0.025
# State |100010001> amplitude 0.068
# State |100010010> amplitude 0.007
# State |100010011> amplitude 0.004
# State |100010100> amplitude 0.002
# State |100010111> amplitude 0.001
# State |100011000> amplitude 0.007
# State |100011010> amplitude 0.002
# State |100011100> amplitude 0.016
# State |100011101> amplitude 0.003
# State |100100000> amplitude 0.003
# State |100100010> amplitude 0.006
# State |100100011> amplitude 0.002
# State |100100100> amplitude 0.001
# State |100101000> amplitude 0.002
# State |100101010> amplitude 0.004
# State |100110000> amplitude 0.004
# State |100110010> amplitude 0.005
# State |100110011> amplitude 0.002
# State |100110110> amplitude 0.001
# State |100111000> amplitude 0.002
# State |100111001> amplitude 0.003
# State |100111011> amplitude 0.001
# State |100111110> amplitude 0.001
# State |101000010> amplitude 0.002
# State |101000011> amplitude 0.004
# State |101000101> amplitude 0.001
# State |101001001> amplitude 0.001
# State |101010000> amplitude 0.004
# State |101010001> amplitude 0.001
# State |101010010> amplitude 0.002
# State |101010011> amplitude 0.001
# State |101010100> amplitude 0.001
# State |101011001> amplitude 0.001
# State |101011110> amplitude 0.002
# State |101100000> amplitude 0.001
# State |101100001> amplitude 0.004
# State |101100011> amplitude 0.002
# State |101100101> amplitude 0.001
# State |101100111> amplitude 0.001
# State |101101000> amplitude 0.001
# State |101101110> amplitude 0.001
# State |101110000> amplitude 0.003
# State |110000000> amplitude 0.002
# State |110000001> amplitude 0.001
# State |110000011> amplitude 0.001
# State |110000100> amplitude 0.001
# State |110000101> amplitude 0.004
# State |110001000> amplitude 0.002
# State |110001001> amplitude 0.002
# State |110001010> amplitude 0.003
# State |110001101> amplitude 0.001
# State |110010000> amplitude 0.004
# State |110010100> amplitude 0.003
# State |110010101> amplitude 0.002
# State |110011000> amplitude 0.001
# State |110011100> amplitude 0.001
# State |110100010> amplitude 0.001
# State |110100100> amplitude 0.001
# State |110101000> amplitude 0.002
# State |110101011> amplitude 0.002
# State |110101100> amplitude 0.001
# State |110101101> amplitude 0.001
# State |110110000> amplitude 0.001
# State |110110001> amplitude 0.001
# State |110110101> amplitude 0.001
# State |110111000> amplitude 0.001
# State |111000000> amplitude 0.001
# State |111000010> amplitude 0.001
# State |111000111> amplitude 0.002
# State |111001011> amplitude 0.001
# State |111010010> amplitude 0.001
# State |111010011> amplitude 0.001
# State |111011000> amplitude 0.001
# State |111101000> amplitude 0.001
# State |111110010> amplitude 0.001
# State |111111000> amplitude 0.001
# State |111111101> amplitude 0.001
# energy :  -16015.592520448408
# State |000000000> amplitude 0.018
# State |000000001> amplitude 0.02
# State |000000010> amplitude 0.028
# State |000000100> amplitude 0.024
# State |000001000> amplitude 0.01
# State |000001010> amplitude 0.008
# State |000001011> amplitude 0.002
# State |000001100> amplitude 0.006
# State |000001101> amplitude 0.001
# State |000001110> amplitude 0.003
# State |000010000> amplitude 0.007
# State |000010001> amplitude 0.005
# State |000010100> amplitude 0.015
# State |000010101> amplitude 0.002
# State |000010110> amplitude 0.001
# State |000011001> amplitude 0.001
# State |000011010> amplitude 0.002
# State |000011101> amplitude 0.002
# State |000100000> amplitude 0.004
# State |000100001> amplitude 0.011
# State |000100010> amplitude 0.008
# State |000100011> amplitude 0.003
# State |000100100> amplitude 0.002
# State |000100101> amplitude 0.001
# State |000101000> amplitude 0.001
# State |000101010> amplitude 0.001
# State |000110000> amplitude 0.001
# State |000110010> amplitude 0.001
# State |000110011> amplitude 0.001
# State |000111000> amplitude 0.001
# State |000111011> amplitude 0.001
# State |000111101> amplitude 0.001
# State |001000000> amplitude 0.018
# State |001000010> amplitude 0.041
# State |001000011> amplitude 0.002
# State |001000100> amplitude 0.019
# State |001001110> amplitude 0.004
# State |001010000> amplitude 0.012
# State |001010001> amplitude 0.001
# State |001010010> amplitude 0.001
# State |001010100> amplitude 0.03
# State |001010101> amplitude 0.004
# State |001011000> amplitude 0.001
# State |001011010> amplitude 0.001
# State |001011101> amplitude 0.001
# State |001100000> amplitude 0.009
# State |001100001> amplitude 0.004
# State |001100010> amplitude 0.079
# State |001100011> amplitude 0.001
# State |001101000> amplitude 0.001
# State |001110000> amplitude 0.001
# State |001110011> amplitude 0.001
# State |001110100> amplitude 0.001
# State |001110110> amplitude 0.004
# State |001110111> amplitude 0.001
# State |001111010> amplitude 0.001
# State |010000000> amplitude 0.034
# State |010000001> amplitude 0.021
# State |010000100> amplitude 0.034
# State |010000110> amplitude 0.005
# State |010001000> amplitude 0.006
# State |010001100> amplitude 0.078
# State |010001110> amplitude 0.002
# State |010010100> amplitude 0.002
# State |010011000> amplitude 0.001
# State |010011001> amplitude 0.002
# State |010011101> amplitude 0.001
# State |010100000> amplitude 0.01
# State |010100001> amplitude 0.034
# State |010100010> amplitude 0.001
# State |010100011> amplitude 0.002
# State |010100100> amplitude 0.001
# State |010101000> amplitude 0.002
# State |010101001> amplitude 0.002
# State |010101110> amplitude 0.001
# State |010110000> amplitude 0.002
# State |011000010> amplitude 0.005
# State |011000100> amplitude 0.001
# State |011001010> amplitude 0.003
# State |011001110> amplitude 0.003
# State |011010100> amplitude 0.003
# State |011011100> amplitude 0.002
# State |011011110> amplitude 0.001
# State |011100000> amplitude 0.003
# State |011100110> amplitude 0.008
# State |011101000> amplitude 0.001
# State |011101010> amplitude 0.003
# State |011101100> amplitude 0.004
# State |011101101> amplitude 0.001
# State |011101110> amplitude 0.003
# State |011110010> amplitude 0.001
# State |100000000> amplitude 0.015
# State |100000001> amplitude 0.04
# State |100000010> amplitude 0.026
# State |100000101> amplitude 0.004
# State |100001000> amplitude 0.007
# State |100001001> amplitude 0.002
# State |100001010> amplitude 0.036
# State |100001100> amplitude 0.001
# State |100001110> amplitude 0.003
# State |100010000> amplitude 0.008
# State |100010001> amplitude 0.072
# State |100010100> amplitude 0.004
# State |100010101> amplitude 0.001
# State |100011000> amplitude 0.003
# State |100011010> amplitude 0.002
# State |100011011> amplitude 0.001
# State |100100000> amplitude 0.001
# State |100100001> amplitude 0.002
# State |100100011> amplitude 0.001
# State |100101000> amplitude 0.003
# State |100101110> amplitude 0.001
# State |100110000> amplitude 0.002
# State |100110011> amplitude 0.002
# State |100110101> amplitude 0.001
# State |100111001> amplitude 0.001
# State |100111111> amplitude 0.001
# State |101000010> amplitude 0.001
# State |101000100> amplitude 0.002
# State |101001010> amplitude 0.001
# State |101010000> amplitude 0.002
# State |101010001> amplitude 0.001
# State |101010011> amplitude 0.002
# State |101010100> amplitude 0.002
# State |101100001> amplitude 0.002
# State |101100011> amplitude 0.002
# State |101101010> amplitude 0.001
# State |101110001> amplitude 0.001
# State |101110010> amplitude 0.001
# State |101110011> amplitude 0.002
# State |110000100> amplitude 0.003
# State |110000101> amplitude 0.001
# State |110001000> amplitude 0.002
# State |110001001> amplitude 0.002
# State |110001100> amplitude 0.002
# State |110001101> amplitude 0.002
# State |110010100> amplitude 0.001
# State |110010101> amplitude 0.002
# State |110011000> amplitude 0.002
# State |110011001> amplitude 0.001
# State |110011101> amplitude 0.002
# State |110100001> amplitude 0.001
# State |110110110> amplitude 0.001
# State |111000010> amplitude 0.001
# State |111001001> amplitude 0.001
# State |111011100> amplitude 0.001
# State |111110010> amplitude 0.001
# State |111110011> amplitude 0.001
# energy :  -9233.61569780048
# State |000000000> amplitude 0.006
# State |000000001> amplitude 0.011
# State |000000010> amplitude 0.007
# State |000000100> amplitude 0.006
# State |000000110> amplitude 0.001
# State |000001000> amplitude 0.028
# State |000001001> amplitude 0.002
# State |000001010> amplitude 0.008
# State |000001100> amplitude 0.008
# State |000010000> amplitude 0.031
# State |000010001> amplitude 0.008
# State |000010010> amplitude 0.006
# State |000010100> amplitude 0.021
# State |000010110> amplitude 0.001
# State |000011000> amplitude 0.013
# State |000011001> amplitude 0.001
# State |000100000> amplitude 0.032
# State |000100001> amplitude 0.015
# State |000100010> amplitude 0.004
# State |000100011> amplitude 0.001
# State |000100100> amplitude 0.004
# State |000100101> amplitude 0.001
# State |000101000> amplitude 0.016
# State |000101110> amplitude 0.001
# State |000110000> amplitude 0.008
# State |000110001> amplitude 0.002
# State |000110010> amplitude 0.001
# State |000110011> amplitude 0.001
# State |000111000> amplitude 0.01
# State |001000000> amplitude 0.009
# State |001000001> amplitude 0.002
# State |001000010> amplitude 0.042
# State |001000011> amplitude 0.001
# State |001000100> amplitude 0.02
# State |001000110> amplitude 0.001
# State |001001000> amplitude 0.006
# State |001001010> amplitude 0.001
# State |001001011> amplitude 0.001
# State |001001100> amplitude 0.001
# State |001010000> amplitude 0.015
# State |001010011> amplitude 0.003
# State |001010100> amplitude 0.002
# State |001010110> amplitude 0.001
# State |001011001> amplitude 0.001
# State |001100000> amplitude 0.001
# State |001100010> amplitude 0.072
# State |001100110> amplitude 0.002
# State |001100111> amplitude 0.001
# State |001101000> amplitude 0.001
# State |001101001> amplitude 0.001
# State |001101110> amplitude 0.001
# State |001110001> amplitude 0.006
# State |001110010> amplitude 0.001
# State |001110011> amplitude 0.001
# State |001110101> amplitude 0.001
# State |001111110> amplitude 0.001
# State |010000000> amplitude 0.013
# State |010000001> amplitude 0.031
# State |010000010> amplitude 0.001
# State |010000100> amplitude 0.049
# State |010000101> amplitude 0.002
# State |010000110> amplitude 0.003
# State |010001000> amplitude 0.006
# State |010001100> amplitude 0.072
# State |010001101> amplitude 0.009
# State |010010000> amplitude 0.002
# State |010010001> amplitude 0.003
# State |010010010> amplitude 0.001
# State |010010100> amplitude 0.001
# State |010010101> amplitude 0.002
# State |010011000> amplitude 0.002
# State |010011011> amplitude 0.001
# State |010011101> amplitude 0.002
# State |010011111> amplitude 0.001
# State |010100000> amplitude 0.007
# State |010100001> amplitude 0.001
# State |010100101> amplitude 0.001
# State |010100110> amplitude 0.002
# State |010101010> amplitude 0.004
# State |010101100> amplitude 0.001
# State |010101111> amplitude 0.002
# State |010110001> amplitude 0.001
# State |010110100> amplitude 0.001
# State |010110101> amplitude 0.001
# State |010111010> amplitude 0.001
# State |010111011> amplitude 0.001
# State |011000000> amplitude 0.003
# State |011000100> amplitude 0.002
# State |011000110> amplitude 0.002
# State |011001000> amplitude 0.001
# State |011001010> amplitude 0.003
# State |011001100> amplitude 0.01
# State |011010100> amplitude 0.001
# State |011010111> amplitude 0.001
# State |011011011> amplitude 0.002
# State |011011110> amplitude 0.002
# State |011100000> amplitude 0.001
# State |011100010> amplitude 0.001
# State |011100011> amplitude 0.002
# State |011100100> amplitude 0.001
# State |011101011> amplitude 0.001
# State |011101100> amplitude 0.003
# State |011101110> amplitude 0.001
# State |011110001> amplitude 0.001
# State |011111001> amplitude 0.001
# State |011111010> amplitude 0.001
# State |100000000> amplitude 0.019
# State |100000001> amplitude 0.038
# State |100000010> amplitude 0.024
# State |100000011> amplitude 0.001
# State |100000100> amplitude 0.001
# State |100000110> amplitude 0.002
# State |100001000> amplitude 0.012
# State |100001001> amplitude 0.001
# State |100001010> amplitude 0.001
# State |100001101> amplitude 0.001
# State |100010000> amplitude 0.006
# State |100010001> amplitude 0.074
# State |100010010> amplitude 0.003
# State |100010011> amplitude 0.003
# State |100011011> amplitude 0.001
# State |100011100> amplitude 0.003
# State |100011110> amplitude 0.001
# State |100011111> amplitude 0.001
# State |100100000> amplitude 0.001
# State |100100010> amplitude 0.001
# State |100100101> amplitude 0.001
# State |100100110> amplitude 0.001
# State |100101001> amplitude 0.001
# State |100101100> amplitude 0.001
# State |100101101> amplitude 0.001
# State |100110000> amplitude 0.001
# State |100110011> amplitude 0.005
# State |100111010> amplitude 0.001
# State |101000010> amplitude 0.005
# State |101000011> amplitude 0.001
# State |101001000> amplitude 0.001
# State |101001001> amplitude 0.001
# State |101001011> amplitude 0.001
# State |101001100> amplitude 0.001
# State |101001111> amplitude 0.001
# State |101010001> amplitude 0.001
# State |101011010> amplitude 0.001
# State |101011100> amplitude 0.002
# State |101100001> amplitude 0.002
# State |101100010> amplitude 0.003
# State |101100011> amplitude 0.001
# State |101100110> amplitude 0.001
# State |101101011> amplitude 0.001
# State |101110001> amplitude 0.001
# State |101110010> amplitude 0.003
# State |101110011> amplitude 0.001
# State |101111001> amplitude 0.001
# State |110000001> amplitude 0.005
# State |110000010> amplitude 0.003
# State |110000111> amplitude 0.001
# State |110001000> amplitude 0.001
# State |110001001> amplitude 0.002
# State |110001100> amplitude 0.003
# State |110001101> amplitude 0.001
# State |110010001> amplitude 0.005
# State |110010011> amplitude 0.003
# State |110010100> amplitude 0.002
# State |110011000> amplitude 0.001
# State |110011001> amplitude 0.001
# State |110011101> amplitude 0.005
# State |110101010> amplitude 0.002
# State |110101011> amplitude 0.001
# State |110101110> amplitude 0.001
# State |110110110> amplitude 0.001
# State |111000000> amplitude 0.002
# State |111000001> amplitude 0.001
# State |111001011> amplitude 0.001
# State |111010000> amplitude 0.001
# State |111011000> amplitude 0.001
# State |111011010> amplitude 0.001
# State |111011111> amplitude 0.001
# State |111100000> amplitude 0.001
# State |111100001> amplitude 0.001
# State |111110000> amplitude 0.001
# State |111110001> amplitude 0.001
# State |111111010> amplitude 0.001
# State |111111110> amplitude 0.001
# energy :  -12523.715047690988
# State |000000000> amplitude 0.004
# State |000000001> amplitude 0.004
# State |000000010> amplitude 0.004
# State |000000100> amplitude 0.004
# State |000000111> amplitude 0.001
# State |000001010> amplitude 0.023
# State |000001011> amplitude 0.001
# State |000001100> amplitude 0.009
# State |000001110> amplitude 0.001
# State |000010000> amplitude 0.002
# State |000010001> amplitude 0.012
# State |000010100> amplitude 0.025
# State |000010101> amplitude 0.001
# State |000011000> amplitude 0.008
# State |000011001> amplitude 0.001
# State |000011010> amplitude 0.001
# State |000011011> amplitude 0.003
# State |000011100> amplitude 0.011
# State |000011110> amplitude 0.001
# State |000100000> amplitude 0.001
# State |000100001> amplitude 0.024
# State |000100010> amplitude 0.013
# State |000100101> amplitude 0.001
# State |000101000> amplitude 0.006
# State |000101001> amplitude 0.001
# State |000101010> amplitude 0.012
# State |000101011> amplitude 0.003
# State |000101101> amplitude 0.001
# State |000101110> amplitude 0.001
# State |000110000> amplitude 0.008
# State |000110001> amplitude 0.007
# State |000110011> amplitude 0.001
# State |000110101> amplitude 0.001
# State |000111000> amplitude 0.007
# State |000111001> amplitude 0.001
# State |000111100> amplitude 0.001
# State |001000000> amplitude 0.007
# State |001000001> amplitude 0.005
# State |001000100> amplitude 0.004
# State |001001001> amplitude 0.001
# State |001001010> amplitude 0.001
# State |001001100> amplitude 0.005
# State |001001110> amplitude 0.001
# State |001010000> amplitude 0.02
# State |001010001> amplitude 0.009
# State |001010010> amplitude 0.002
# State |001010100> amplitude 0.04
# State |001010110> amplitude 0.001
# State |001011101> amplitude 0.001
# State |001100000> amplitude 0.011
# State |001100001> amplitude 0.008
# State |001100010> amplitude 0.085
# State |001100100> amplitude 0.001
# State |001100110> amplitude 0.002
# State |001101001> amplitude 0.001
# State |001110000> amplitude 0.007
# State |001110001> amplitude 0.018
# State |001110011> amplitude 0.001
# State |001111100> amplitude 0.004
# State |010000000> amplitude 0.004
# State |010000001> amplitude 0.003
# State |010000010> amplitude 0.002
# State |010000011> amplitude 0.002
# State |010000100> amplitude 0.001
# State |010001000> amplitude 0.014
# State |010001001> amplitude 0.002
# State |010001010> amplitude 0.009
# State |010001100> amplitude 0.073
# State |010001101> amplitude 0.001
# State |010010010> amplitude 0.001
# State |010011000> amplitude 0.001
# State |010011001> amplitude 0.002
# State |010011101> amplitude 0.001
# State |010100000> amplitude 0.028
# State |010100001> amplitude 0.047
# State |010100010> amplitude 0.012
# State |010101000> amplitude 0.01
# State |010101010> amplitude 0.029
# State |010101101> amplitude 0.001
# State |010111001> amplitude 0.003
# State |010111010> amplitude 0.001
# State |011001000> amplitude 0.001
# State |011001010> amplitude 0.002
# State |011001100> amplitude 0.001
# State |011001101> amplitude 0.001
# State |011001110> amplitude 0.001
# State |011010011> amplitude 0.001
# State |011010100> amplitude 0.001
# State |011011101> amplitude 0.001
# State |011100000> amplitude 0.001
# State |011100100> amplitude 0.002
# State |011100110> amplitude 0.001
# State |011101001> amplitude 0.001
# State |011101010> amplitude 0.001
# State |011101011> amplitude 0.001
# State |011110000> amplitude 0.002
# State |011111010> amplitude 0.001
# State |011111011> amplitude 0.002
# State |011111100> amplitude 0.001
# State |100000000> amplitude 0.005
# State |100000001> amplitude 0.001
# State |100000011> amplitude 0.001
# State |100000100> amplitude 0.003
# State |100000110> amplitude 0.001
# State |100001000> amplitude 0.03
# State |100001001> amplitude 0.001
# State |100001010> amplitude 0.039
# State |100001011> amplitude 0.002
# State |100001100> amplitude 0.013
# State |100001101> amplitude 0.001
# State |100010000> amplitude 0.02
# State |100010001> amplitude 0.07
# State |100010010> amplitude 0.002
# State |100010100> amplitude 0.012
# State |100011000> amplitude 0.008
# State |100011100> amplitude 0.022
# State |100100010> amplitude 0.001
# State |100100011> amplitude 0.001
# State |100100110> amplitude 0.001
# State |100101001> amplitude 0.001
# State |100110010> amplitude 0.003
# State |100110011> amplitude 0.001
# State |100111000> amplitude 0.002
# State |100111001> amplitude 0.001
# State |100111010> amplitude 0.006
# State |100111101> amplitude 0.001
# State |101000001> amplitude 0.001
# State |101001010> amplitude 0.002
# State |101010000> amplitude 0.001
# State |101011000> amplitude 0.001
# State |101011100> amplitude 0.001
# State |101100010> amplitude 0.001
# State |101100110> amplitude 0.003
# State |101101000> amplitude 0.003
# State |110000100> amplitude 0.001
# State |110001000> amplitude 0.004
# State |110001001> amplitude 0.001
# State |110001111> amplitude 0.001
# State |110010100> amplitude 0.004
# State |110100000> amplitude 0.001
# State |110100001> amplitude 0.002
# State |110101000> amplitude 0.002
# State |110110000> amplitude 0.001
# State |110111110> amplitude 0.001
# State |111000000> amplitude 0.001
# State |111001101> amplitude 0.001
# State |111010001> amplitude 0.001
# State |111010010> amplitude 0.003
# State |111100000> amplitude 0.001
# State |111100010> amplitude 0.001
# State |111110000> amplitude 0.001
# State |111110110> amplitude 0.001
# State |111111010> amplitude 0.001
# energy :  -15955.118508160624
# State |000000000> amplitude 0.014
# State |000000001> amplitude 0.001
# State |000000010> amplitude 0.001
# State |000000011> amplitude 0.001
# State |000000100> amplitude 0.007
# State |000000101> amplitude 0.001
# State |000000110> amplitude 0.002
# State |000001000> amplitude 0.001
# State |000001001> amplitude 0.001
# State |000001010> amplitude 0.024
# State |000001100> amplitude 0.012
# State |000001110> amplitude 0.009
# State |000010001> amplitude 0.021
# State |000010100> amplitude 0.014
# State |000010101> amplitude 0.004
# State |000011000> amplitude 0.001
# State |000011100> amplitude 0.005
# State |000011110> amplitude 0.001
# State |000100000> amplitude 0.001
# State |000100001> amplitude 0.027
# State |000100010> amplitude 0.011
# State |000100011> amplitude 0.005
# State |000100100> amplitude 0.001
# State |000100110> amplitude 0.002
# State |000101000> amplitude 0.001
# State |000101010> amplitude 0.007
# State |000101011> amplitude 0.001
# State |000110000> amplitude 0.001
# State |000110001> amplitude 0.003
# State |000111000> amplitude 0.002
# State |001000000> amplitude 0.001
# State |001000001> amplitude 0.004
# State |001000010> amplitude 0.017
# State |001000100> amplitude 0.018
# State |001000110> amplitude 0.005
# State |001001010> amplitude 0.013
# State |001001100> amplitude 0.002
# State |001001110> amplitude 0.005
# State |001010000> amplitude 0.024
# State |001010001> amplitude 0.008
# State |001010010> amplitude 0.009
# State |001010011> amplitude 0.001
# State |001010100> amplitude 0.057
# State |001010101> amplitude 0.003
# State |001010111> amplitude 0.001
# State |001011010> amplitude 0.002
# State |001011100> amplitude 0.001
# State |001100000> amplitude 0.013
# State |001100001> amplitude 0.006
# State |001100010> amplitude 0.018
# State |001100011> amplitude 0.001
# State |001100100> amplitude 0.004
# State |001100110> amplitude 0.001
# State |001101010> amplitude 0.003
# State |001110000> amplitude 0.009
# State |001110001> amplitude 0.006
# State |001110010> amplitude 0.001
# State |001110100> amplitude 0.001
# State |010000001> amplitude 0.03
# State |010000010> amplitude 0.003
# State |010000011> amplitude 0.001
# State |010000100> amplitude 0.025
# State |010001000> amplitude 0.016
# State |010001001> amplitude 0.004
# State |010001010> amplitude 0.008
# State |010001011> amplitude 0.001
# State |010001100> amplitude 0.015
# State |010001110> amplitude 0.002
# State |010010001> amplitude 0.004
# State |010010100> amplitude 0.012
# State |010010101> amplitude 0.001
# State |010010111> amplitude 0.001
# State |010011110> amplitude 0.001
# State |010100000> amplitude 0.025
# State |010100001> amplitude 0.042
# State |010100010> amplitude 0.006
# State |010100011> amplitude 0.001
# State |010100100> amplitude 0.008
# State |010101000> amplitude 0.006
# State |010101001> amplitude 0.001
# State |010101010> amplitude 0.003
# State |010101011> amplitude 0.001
# State |010101100> amplitude 0.006
# State |010110100> amplitude 0.002
# State |011000000> amplitude 0.004
# State |011000010> amplitude 0.002
# State |011000011> amplitude 0.002
# State |011000100> amplitude 0.003
# State |011010101> amplitude 0.001
# State |011011001> amplitude 0.001
# State |011100000> amplitude 0.014
# State |011100001> amplitude 0.001
# State |011100010> amplitude 0.003
# State |011100100> amplitude 0.004
# State |011110000> amplitude 0.001
# State |011110100> amplitude 0.002
# State |100000000> amplitude 0.001
# State |100000001> amplitude 0.023
# State |100000010> amplitude 0.04
# State |100000011> amplitude 0.009
# State |100000100> amplitude 0.004
# State |100000101> amplitude 0.001
# State |100000111> amplitude 0.001
# State |100001000> amplitude 0.024
# State |100001001> amplitude 0.012
# State |100001010> amplitude 0.046
# State |100001100> amplitude 0.006
# State |100001110> amplitude 0.002
# State |100010000> amplitude 0.011
# State |100010001> amplitude 0.023
# State |100010010> amplitude 0.004
# State |100010100> amplitude 0.006
# State |100010101> amplitude 0.002
# State |100011000> amplitude 0.004
# State |100011001> amplitude 0.001
# State |100011010> amplitude 0.001
# State |100011100> amplitude 0.004
# State |100100001> amplitude 0.02
# State |100100010> amplitude 0.003
# State |100100011> amplitude 0.008
# State |100101011> amplitude 0.001
# State |100110001> amplitude 0.001
# State |100110111> amplitude 0.001
# State |101000000> amplitude 0.001
# State |101000010> amplitude 0.004
# State |101001101> amplitude 0.001
# State |101010000> amplitude 0.006
# State |101010010> amplitude 0.004
# State |101010100> amplitude 0.001
# State |101100001> amplitude 0.001
# State |101101001> amplitude 0.001
# State |110000000> amplitude 0.004
# State |110000001> amplitude 0.008
# State |110000011> amplitude 0.001
# State |110000110> amplitude 0.001
# State |110001000> amplitude 0.009
# State |110001001> amplitude 0.006
# State |110001011> amplitude 0.001
# State |110001100> amplitude 0.001
# State |110011010> amplitude 0.001
# State |110011100> amplitude 0.001
# State |110101011> amplitude 0.001
# State |110110000> amplitude 0.001
# State |110111010> amplitude 0.001
# State |111000000> amplitude 0.001
# State |111000011> amplitude 0.001
# State |111100001> amplitude 0.001
# State |111100100> amplitude 0.002
# State |111110011> amplitude 0.001
# State |111111000> amplitude 0.001
# energy :  -24350.50050272797
# State |000000000> amplitude 0.007
# State |000000001> amplitude 0.004
# State |000000010> amplitude 0.006
# State |000000011> amplitude 0.001
# State |000000100> amplitude 0.007
# State |000000101> amplitude 0.001
# State |000000110> amplitude 0.002
# State |000000111> amplitude 0.001
# State |000001000> amplitude 0.004
# State |000001100> amplitude 0.019
# State |000010000> amplitude 0.005
# State |000010001> amplitude 0.023
# State |000010100> amplitude 0.001
# State |000010110> amplitude 0.001
# State |000011001> amplitude 0.001
# State |000011100> amplitude 0.002
# State |000100000> amplitude 0.004
# State |000100001> amplitude 0.002
# State |000100010> amplitude 0.017
# State |000100011> amplitude 0.001
# State |000100110> amplitude 0.001
# State |000101000> amplitude 0.001
# State |000101010> amplitude 0.005
# State |000110000> amplitude 0.003
# State |000111011> amplitude 0.001
# State |001000000> amplitude 0.006
# State |001000001> amplitude 0.001
# State |001000010> amplitude 0.032
# State |001000100> amplitude 0.004
# State |001001100> amplitude 0.004
# State |001001110> amplitude 0.001
# State |001010000> amplitude 0.001
# State |001010100> amplitude 0.001
# State |001100000> amplitude 0.018
# State |001100010> amplitude 0.174
# State |001100100> amplitude 0.003
# State |001101010> amplitude 0.001
# State |001101100> amplitude 0.003
# State |001110000> amplitude 0.001
# State |001111100> amplitude 0.001
# State |010000000> amplitude 0.003
# State |010000001> amplitude 0.005
# State |010000010> amplitude 0.001
# State |010000100> amplitude 0.032
# State |010000101> amplitude 0.002
# State |010001000> amplitude 0.017
# State |010001001> amplitude 0.004
# State |010001010> amplitude 0.001
# State |010001100> amplitude 0.196
# State |010001101> amplitude 0.003
# State |010010001> amplitude 0.003
# State |010010100> amplitude 0.002
# State |010011000> amplitude 0.001
# State |010011001> amplitude 0.005
# State |010011010> amplitude 0.001
# State |010011100> amplitude 0.001
# State |010100001> amplitude 0.002
# State |010100100> amplitude 0.002
# State |010101000> amplitude 0.001
# State |010101010> amplitude 0.002
# State |010101100> amplitude 0.001
# State |010111001> amplitude 0.001
# State |011000100> amplitude 0.001
# State |011000101> amplitude 0.001
# State |011001100> amplitude 0.006
# State |011001101> amplitude 0.001
# State |011010000> amplitude 0.001
# State |011100011> amplitude 0.001
# State |011101010> amplitude 0.001
# State |011101100> amplitude 0.001
# State |100000000> amplitude 0.004
# State |100000001> amplitude 0.029
# State |100000010> amplitude 0.007
# State |100000100> amplitude 0.003
# State |100000101> amplitude 0.001
# State |100001000> amplitude 0.002
# State |100001010> amplitude 0.004
# State |100001011> amplitude 0.001
# State |100010000> amplitude 0.018
# State |100010001> amplitude 0.211
# State |100010010> amplitude 0.004
# State |100010011> amplitude 0.002
# State |100010111> amplitude 0.001
# State |100011001> amplitude 0.002
# State |100100000> amplitude 0.001
# State |100100001> amplitude 0.001
# State |100100010> amplitude 0.006
# State |100110001> amplitude 0.002
# State |100110010> amplitude 0.004
# State |100110011> amplitude 0.002
# State |101000000> amplitude 0.001
# State |101000010> amplitude 0.001
# State |101000110> amplitude 0.001
# State |101010100> amplitude 0.001
# State |101010101> amplitude 0.001
# State |101011001> amplitude 0.001
# State |101100000> amplitude 0.001
# State |101100010> amplitude 0.006
# State |101100110> amplitude 0.001
# State |101110001> amplitude 0.001
# State |101110011> amplitude 0.004
# State |101110110> amplitude 0.001
# State |110001000> amplitude 0.001
# State |110001100> amplitude 0.001
# State |110011100> amplitude 0.001
# State |111000000> amplitude 0.001
# State |111010001> amplitude 0.001

# %%
import matplotlib.pyplot as plt
plt.plot(nb_layers, energy_list, label =' QAOA energy')
plt.scatter(nb_layers, energy_list)
plt.plot([0, 9], [-35998, -35998], "--", label = "optimal value")
# Add labels and a title
plt.xlabel('Number of layers')
plt.ylabel('Energy (arbitrary unit)')
plt.title('Converged QAOA Energy as a function of the number of layer')
plt.legend(loc='best')
plt.grid()
# Show the plot
plt.show()

# %% [markdown]
# # 4) A Quantum Heuristic
# Our idea was to compare the QAOA algorithm (whose convergence is proved if $p$ is large enough) to a much simpler heuristic.
# Instead of preparing the state $\ket{\Phi(\vec{\gamma},\vec{\beta} )}$ we prepare the state : $$\ket{\Phi(\vec{\theta})} = \prod_i e^{-i\theta_i X_i}\ket{0}$$
# The idea is that modifying the parameters $\vec{\theta}$ allows us to reach any state of the basis (some of which are optimal). The problem is that any of these state is a vanishing point for the energy gradient (see the detailed report), so starting from a random $\vec{\theta}$ is likely to yield a non optimal state. However, we can expect the convergence to an optimal state to be more likely than to another state because the gradients are more likely to be directed towards them (since their energy is lower). Thus we designed a random alorithm which starts with a random $\vec{\theta}$ and performs the desired amount of times the optimization. We then choose the state whose frequency is the biggest.

# %%
def heuristic_run():
    observable = problem.get_observable()
    prog = Program()
    reg = prog.qalloc(nb_cities**2)
    var =  [ prog.new_var(float,'theta'+str(i)) for i in range(nb_cities**2)]

    # if we want to add dephasing :
    #var2 = [ prog.new_var(float,'phi'+str(i)) for i in range(nb_cities**2)]

    # we just apply a RX(theta_i) gate on every qubit
    for i in range(nb_cities**2):
        prog.apply(RX(var[i]),reg[i])

        #dephasing : prog.apply(PH(var2[i]), reg[i])
    # From there on, everything is identical to the QAOA code
    circ = prog.to_circ()
    job = circ.to_job(observable=observable)
    # initialize the optimizer
    optimize =ScipyMinimizePlugin(method="BFGS", tol=1e-5, options={"maxiter": 150}) 
    qpu = PyLinalg()
    # Once again create the stack
    stack =  optimize | qpu 
    # get the result
    result = stack.submit(job) 
    energy=result.value
    # We bind the variables using the optimized values
    circuit = job.circuit.bind_variables(result.parameter_map) 
    # A second job allowing us to assess the corresponding state using 10000 shots
    job = circuit.to_job(nbshots = 10000) 
    qpu = PyLinalg()
    result = qpu.submit(job) # result
    probasRes = np.zeros(2**(nb_cities**2))
    for sample in result:
        return( str(sample.state), sample.probability, energy)

def probabilistic_heuristic(n_runs):
    solution_dict = {}
    energy_dict={}
    for _ in range(n_runs):
        state, value, energy = heuristic_run()
        energy_dict[state]=energy
        if state in solution_dict : 
            solution_dict[state]+=1
        else : 
            solution_dict[state] = 1
    state=max(solution_dict, key = solution_dict.get)
    return(state,energy_dict[state])

# %%
energy_QAOA=[]
energy_heuristic=[]
run_number=[]
for i in range(1,10):
    run_number.append(i)
    energy1=run_qaoa(i)
    energy_QAOA.append(energy1)
    state, value, energy2 = heuristic_run()
    energy_heuristic.append(energy2)
# Out:
# energy :  52143.353606995326
# State |000000000> amplitude 0.007
# State |000000010> amplitude 0.002
# State |000000011> amplitude 0.002
# State |000000100> amplitude 0.003
# State |000000101> amplitude 0.002
# State |000000110> amplitude 0.004
# State |000000111> amplitude 0.001
# State |000001000> amplitude 0.003
# State |000001001> amplitude 0.003
# State |000001010> amplitude 0.001
# State |000001011> amplitude 0.004
# State |000001100> amplitude 0.003
# State |000001101> amplitude 0.002
# State |000010000> amplitude 0.001
# State |000010001> amplitude 0.002
# State |000010010> amplitude 0.002
# State |000010100> amplitude 0.001
# State |000010110> amplitude 0.005
# State |000011000> amplitude 0.003
# State |000011011> amplitude 0.005
# State |000011100> amplitude 0.001
# State |000011101> amplitude 0.005
# State |000011111> amplitude 0.002
# State |000100000> amplitude 0.001
# State |000100001> amplitude 0.005
# State |000100010> amplitude 0.003
# State |000100100> amplitude 0.004
# State |000100101> amplitude 0.001
# State |000101000> amplitude 0.003
# State |000101010> amplitude 0.001
# State |000101011> amplitude 0.002
# State |000101101> amplitude 0.006
# State |000101110> amplitude 0.004
# State |000101111> amplitude 0.003
# State |000110000> amplitude 0.001
# State |000110001> amplitude 0.001
# State |000110011> amplitude 0.004
# State |000110100> amplitude 0.001
# State |000110101> amplitude 0.001
# State |000110110> amplitude 0.005
# State |000110111> amplitude 0.001
# State |000111010> amplitude 0.003
# State |000111101> amplitude 0.001
# State |000111111> amplitude 0.001
# State |001000001> amplitude 0.002
# State |001000010> amplitude 0.003
# State |001000101> amplitude 0.002
# State |001000110> amplitude 0.004
# State |001001000> amplitude 0.002
# State |001001010> amplitude 0.001
# State |001001100> amplitude 0.001
# State |001001111> amplitude 0.002
# State |001010001> amplitude 0.002
# State |001010011> amplitude 0.006
# State |001010100> amplitude 0.003
# State |001010101> amplitude 0.001
# State |001010111> amplitude 0.003
# State |001011010> amplitude 0.004
# State |001011011> amplitude 0.001
# State |001011100> amplitude 0.004
# State |001011101> amplitude 0.002
# State |001011110> amplitude 0.001
# State |001011111> amplitude 0.001
# State |001100001> amplitude 0.005
# State |001100010> amplitude 0.005
# State |001100011> amplitude 0.001
# State |001100101> amplitude 0.001
# State |001100111> amplitude 0.004
# State |001101000> amplitude 0.002
# State |001101001> amplitude 0.002
# State |001101011> amplitude 0.005
# State |001101100> amplitude 0.003
# State |001101110> amplitude 0.005
# State |001101111> amplitude 0.002
# State |001110011> amplitude 0.001
# State |001110100> amplitude 0.002
# State |001110101> amplitude 0.007
# State |001110110> amplitude 0.004
# State |001110111> amplitude 0.001
# State |001111010> amplitude 0.004
# State |001111011> amplitude 0.003
# State |001111100> amplitude 0.002
# State |001111101> amplitude 0.004
# State |001111110> amplitude 0.003
# State |010000000> amplitude 0.001
# State |010000010> amplitude 0.002
# State |010000011> amplitude 0.001
# State |010000100> amplitude 0.003
# State |010000101> amplitude 0.002
# State |010000111> amplitude 0.002
# State |010001000> amplitude 0.002
# State |010001001> amplitude 0.002
# State |010001010> amplitude 0.001
# State |010001100> amplitude 0.005
# State |010001110> amplitude 0.001
# State |010001111> amplitude 0.005
# State |010010000> amplitude 0.001
# State |010010010> amplitude 0.002
# State |010010011> amplitude 0.003
# State |010010101> amplitude 0.001
# State |010010110> amplitude 0.001
# State |010010111> amplitude 0.002
# State |010011000> amplitude 0.002
# State |010011001> amplitude 0.005
# State |010011011> amplitude 0.001
# State |010011101> amplitude 0.002
# State |010011110> amplitude 0.009
# State |010100000> amplitude 0.001
# State |010100001> amplitude 0.001
# State |010100100> amplitude 0.001
# State |010100110> amplitude 0.008
# State |010100111> amplitude 0.002
# State |010101000> amplitude 0.001
# State |010101001> amplitude 0.007
# State |010101011> amplitude 0.005
# State |010101100> amplitude 0.001
# State |010101101> amplitude 0.003
# State |010101110> amplitude 0.001
# State |010101111> amplitude 0.002
# State |010110000> amplitude 0.001
# State |010110001> amplitude 0.004
# State |010110010> amplitude 0.001
# State |010110011> amplitude 0.002
# State |010110100> amplitude 0.007
# State |010110101> amplitude 0.004
# State |010110110> amplitude 0.001
# State |010110111> amplitude 0.005
# State |010111000> amplitude 0.001
# State |010111001> amplitude 0.002
# State |010111010> amplitude 0.001
# State |010111011> amplitude 0.005
# State |010111100> amplitude 0.002
# State |010111101> amplitude 0.004
# State |010111110> amplitude 0.004
# State |011000000> amplitude 0.004
# State |011000011> amplitude 0.005
# State |011000100> amplitude 0.002
# State |011000101> amplitude 0.003
# State |011000110> amplitude 0.002
# State |011000111> amplitude 0.002
# State |011001010> amplitude 0.007
# State |011001101> amplitude 0.005
# State |011001111> amplitude 0.003
# State |011010000> amplitude 0.005
# State |011010100> amplitude 0.003
# State |011010101> amplitude 0.002
# State |011010110> amplitude 0.001
# State |011010111> amplitude 0.001
# State |011011000> amplitude 0.005
# State |011011100> amplitude 0.003
# State |011011101> amplitude 0.001
# State |011011111> amplitude 0.001
# State |011100001> amplitude 0.004
# State |011100011> amplitude 0.005
# State |011101000> amplitude 0.006
# State |011101010> amplitude 0.001
# State |011101100> amplitude 0.003
# State |011101101> amplitude 0.002
# State |011101110> amplitude 0.004
# State |011101111> amplitude 0.003
# State |011110000> amplitude 0.002
# State |011110001> amplitude 0.012
# State |011110010> amplitude 0.001
# State |011110100> amplitude 0.002
# State |011110101> amplitude 0.003
# State |011110110> amplitude 0.002
# State |011110111> amplitude 0.003
# State |011111000> amplitude 0.001
# State |011111010> amplitude 0.008
# State |011111011> amplitude 0.001
# State |011111100> amplitude 0.001
# State |011111110> amplitude 0.004
# State |100000000> amplitude 0.002
# State |100000001> amplitude 0.005
# State |100000011> amplitude 0.002
# State |100001000> amplitude 0.002
# State |100001001> amplitude 0.001
# State |100001010> amplitude 0.003
# State |100001011> amplitude 0.001
# State |100001100> amplitude 0.003
# State |100001101> amplitude 0.004
# State |100001110> amplitude 0.002
# State |100001111> amplitude 0.004
# State |100010000> amplitude 0.002
# State |100010001> amplitude 0.004
# State |100010011> amplitude 0.002
# State |100010100> amplitude 0.002
# State |100010101> amplitude 0.001
# State |100010111> amplitude 0.003
# State |100011000> amplitude 0.001
# State |100011001> amplitude 0.001
# State |100011010> amplitude 0.006
# State |100011011> amplitude 0.006
# State |100011110> amplitude 0.004
# State |100011111> amplitude 0.003
# State |100100000> amplitude 0.001
# State |100100001> amplitude 0.001
# State |100100011> amplitude 0.002
# State |100100111> amplitude 0.004
# State |100101000> amplitude 0.001
# State |100101001> amplitude 0.003
# State |100101010> amplitude 0.007
# State |100101011> amplitude 0.002
# State |100101100> amplitude 0.002
# State |100101110> amplitude 0.001
# State |100101111> amplitude 0.003
# State |100110000> amplitude 0.001
# State |100110001> amplitude 0.001
# State |100110010> amplitude 0.006
# State |100110011> amplitude 0.004
# State |100110100> amplitude 0.003
# State |100110101> amplitude 0.004
# State |100110111> amplitude 0.005
# State |100111000> amplitude 0.001
# State |100111001> amplitude 0.002
# State |100111010> amplitude 0.001
# State |100111011> amplitude 0.005
# State |100111100> amplitude 0.002
# State |100111101> amplitude 0.001
# State |100111110> amplitude 0.005
# State |101000000> amplitude 0.001
# State |101000010> amplitude 0.002
# State |101000011> amplitude 0.005
# State |101000100> amplitude 0.001
# State |101000101> amplitude 0.012
# State |101000110> amplitude 0.002
# State |101000111> amplitude 0.006
# State |101001000> amplitude 0.006
# State |101001001> amplitude 0.001
# State |101001010> amplitude 0.001
# State |101001100> amplitude 0.004
# State |101001101> amplitude 0.002
# State |101001110> amplitude 0.002
# State |101001111> amplitude 0.001
# State |101010001> amplitude 0.002
# State |101010100> amplitude 0.004
# State |101010101> amplitude 0.005
# State |101010110> amplitude 0.002
# State |101011001> amplitude 0.004
# State |101011010> amplitude 0.002
# State |101011011> amplitude 0.001
# State |101011100> amplitude 0.01
# State |101011110> amplitude 0.008
# State |101011111> amplitude 0.002
# State |101100000> amplitude 0.001
# State |101100001> amplitude 0.011
# State |101100011> amplitude 0.002
# State |101100101> amplitude 0.002
# State |101100110> amplitude 0.007
# State |101100111> amplitude 0.002
# State |101101000> amplitude 0.006
# State |101101001> amplitude 0.001
# State |101101010> amplitude 0.006
# State |101101110> amplitude 0.001
# State |101110000> amplitude 0.008
# State |101110010> amplitude 0.003
# State |101110110> amplitude 0.001
# State |101111001> amplitude 0.002
# State |101111010> amplitude 0.005
# State |101111011> amplitude 0.003
# State |101111100> amplitude 0.004
# State |101111110> amplitude 0.001
# State |110000000> amplitude 0.002
# State |110000001> amplitude 0.002
# State |110000011> amplitude 0.002
# State |110000100> amplitude 0.002
# State |110000101> amplitude 0.001
# State |110000110> amplitude 0.009
# State |110000111> amplitude 0.002
# State |110001010> amplitude 0.004
# State |110001011> amplitude 0.001
# State |110001100> amplitude 0.002
# State |110001101> amplitude 0.001
# State |110001110> amplitude 0.004
# State |110001111> amplitude 0.002
# State |110010010> amplitude 0.001
# State |110010011> amplitude 0.006
# State |110010100> amplitude 0.008
# State |110010101> amplitude 0.001
# State |110010111> amplitude 0.002
# State |110011000> amplitude 0.007
# State |110011001> amplitude 0.007
# State |110011010> amplitude 0.002
# State |110011011> amplitude 0.002
# State |110011100> amplitude 0.001
# State |110011101> amplitude 0.006
# State |110011111> amplitude 0.001
# State |110100000> amplitude 0.002
# State |110100001> amplitude 0.001
# State |110100010> amplitude 0.002
# State |110100100> amplitude 0.001
# State |110100101> amplitude 0.002
# State |110100111> amplitude 0.002
# State |110101000> amplitude 0.002
# State |110101001> amplitude 0.004
# State |110101010> amplitude 0.006
# State |110101011> amplitude 0.007
# State |110101100> amplitude 0.003
# State |110101101> amplitude 0.001
# State |110101110> amplitude 0.001
# State |110101111> amplitude 0.003
# State |110110000> amplitude 0.009
# State |110110001> amplitude 0.009
# State |110110101> amplitude 0.002
# State |110110110> amplitude 0.001
# State |110111001> amplitude 0.001
# State |110111010> amplitude 0.005
# State |110111100> amplitude 0.002
# State |110111101> amplitude 0.006
# State |110111111> amplitude 0.001
# State |111000001> amplitude 0.002
# State |111000010> amplitude 0.003
# State |111000011> amplitude 0.001
# State |111000101> amplitude 0.001
# State |111000110> amplitude 0.002
# State |111001000> amplitude 0.001
# State |111001001> amplitude 0.001
# State |111001011> amplitude 0.001
# State |111001100> amplitude 0.003
# State |111001101> amplitude 0.001
# State |111010001> amplitude 0.005
# State |111010010> amplitude 0.002
# State |111010011> amplitude 0.002
# State |111010100> amplitude 0.002
# State |111010101> amplitude 0.001
# State |111010110> amplitude 0.002
# State |111010111> amplitude 0.001
# State |111011000> amplitude 0.001
# State |111011001> amplitude 0.003
# State |111011010> amplitude 0.002
# State |111011011> amplitude 0.001
# State |111011100> amplitude 0.001
# State |111011110> amplitude 0.003
# State |111011111> amplitude 0.002
# State |111100000> amplitude 0.001
# State |111100001> amplitude 0.002
# State |111100010> amplitude 0.002
# State |111100100> amplitude 0.002
# State |111100101> amplitude 0.002
# State |111100110> amplitude 0.001
# State |111101001> amplitude 0.001
# State |111101010> amplitude 0.002
# State |111101011> amplitude 0.003
# State |111101100> amplitude 0.001
# State |111101101> amplitude 0.001
# State |111101110> amplitude 0.001
# State |111101111> amplitude 0.001
# State |111110000> amplitude 0.002
# State |111110010> amplitude 0.004
# State |111110011> amplitude 0.003
# State |111110100> amplitude 0.002
# State |111110101> amplitude 0.003
# State |111110110> amplitude 0.002
# State |111110111> amplitude 0.001
# State |111111111> amplitude 0.001
# energy :  -13595.5488817937
# State |000000000> amplitude 0.074
# State |000000001> amplitude 0.004
# State |000000010> amplitude 0.005
# State |000000011> amplitude 0.001
# State |000000100> amplitude 0.007
# State |000000110> amplitude 0.001
# State |000001000> amplitude 0.004
# State |000001001> amplitude 0.001
# State |000001010> amplitude 0.003
# State |000001100> amplitude 0.034
# State |000001110> amplitude 0.005
# State |000010000> amplitude 0.002
# State |000010001> amplitude 0.047
# State |000010010> amplitude 0.002
# State |000010100> amplitude 0.003
# State |000010101> amplitude 0.002
# State |000010110> amplitude 0.001
# State |000011001> amplitude 0.001
# State |000011100> amplitude 0.007
# State |000011101> amplitude 0.001
# State |000100000> amplitude 0.002
# State |000100001> amplitude 0.001
# State |000100010> amplitude 0.027
# State |000100011> amplitude 0.005
# State |000100100> amplitude 0.002
# State |000101010> amplitude 0.006
# State |000101110> amplitude 0.002
# State |000110001> amplitude 0.003
# State |000110010> amplitude 0.001
# State |000110011> amplitude 0.001
# State |000110101> amplitude 0.001
# State |000110111> amplitude 0.001
# State |000111000> amplitude 0.001
# State |000111011> amplitude 0.003
# State |000111100> amplitude 0.001
# State |000111110> amplitude 0.001
# State |001000000> amplitude 0.007
# State |001000001> amplitude 0.001
# State |001000010> amplitude 0.028
# State |001001000> amplitude 0.001
# State |001001001> amplitude 0.001
# State |001001010> amplitude 0.004
# State |001001011> amplitude 0.002
# State |001001100> amplitude 0.009
# State |001001111> amplitude 0.001
# State |001010000> amplitude 0.005
# State |001010001> amplitude 0.003
# State |001010100> amplitude 0.002
# State |001011100> amplitude 0.004
# State |001100000> amplitude 0.038
# State |001100001> amplitude 0.002
# State |001100010> amplitude 0.08
# State |001100100> amplitude 0.006
# State |001100110> amplitude 0.001
# State |001101010> amplitude 0.003
# State |001101011> amplitude 0.004
# State |001101100> amplitude 0.002
# State |001101110> amplitude 0.004
# State |001101111> amplitude 0.001
# State |001110000> amplitude 0.002
# State |001110001> amplitude 0.002
# State |001110010> amplitude 0.002
# State |001110100> amplitude 0.007
# State |001111010> amplitude 0.001
# State |010000000> amplitude 0.009
# State |010000001> amplitude 0.004
# State |010000100> amplitude 0.029
# State |010000110> amplitude 0.001
# State |010001000> amplitude 0.038
# State |010001001> amplitude 0.007
# State |010001011> amplitude 0.001
# State |010001100> amplitude 0.083
# State |010001101> amplitude 0.005
# State |010010000> amplitude 0.001
# State |010010001> amplitude 0.006
# State |010010011> amplitude 0.001
# State |010010100> amplitude 0.001
# State |010010101> amplitude 0.002
# State |010010111> amplitude 0.001
# State |010011001> amplitude 0.002
# State |010011100> amplitude 0.001
# State |010011101> amplitude 0.004
# State |010011110> amplitude 0.001
# State |010100001> amplitude 0.005
# State |010100010> amplitude 0.002
# State |010100100> amplitude 0.004
# State |010100111> amplitude 0.001
# State |010101000> amplitude 0.005
# State |010101001> amplitude 0.004
# State |010101010> amplitude 0.001
# State |010101101> amplitude 0.002
# State |010110001> amplitude 0.005
# State |010111100> amplitude 0.002
# State |011001011> amplitude 0.001
# State |011001100> amplitude 0.001
# State |011001111> amplitude 0.001
# State |011011100> amplitude 0.001
# State |011011110> amplitude 0.001
# State |011100000> amplitude 0.002
# State |011101010> amplitude 0.001
# State |011101100> amplitude 0.005
# State |011101111> amplitude 0.001
# State |011110010> amplitude 0.004
# State |011111000> amplitude 0.001
# State |100000000> amplitude 0.007
# State |100000001> amplitude 0.03
# State |100000010> amplitude 0.003
# State |100001000> amplitude 0.001
# State |100001001> amplitude 0.002
# State |100001100> amplitude 0.001
# State |100001110> amplitude 0.001
# State |100010000> amplitude 0.039
# State |100010001> amplitude 0.081
# State |100010010> amplitude 0.01
# State |100010011> amplitude 0.004
# State |100010100> amplitude 0.001
# State |100010101> amplitude 0.001
# State |100011000> amplitude 0.005
# State |100011010> amplitude 0.002
# State |100011011> amplitude 0.003
# State |100011100> amplitude 0.001
# State |100011110> amplitude 0.002
# State |100100000> amplitude 0.002
# State |100100001> amplitude 0.004
# State |100100010> amplitude 0.008
# State |100100011> amplitude 0.001
# State |100100110> amplitude 0.001
# State |100101001> amplitude 0.001
# State |100101010> amplitude 0.001
# State |100101011> amplitude 0.001
# State |100101110> amplitude 0.001
# State |100110010> amplitude 0.004
# State |100110011> amplitude 0.004
# State |100110101> amplitude 0.001
# State |100111001> amplitude 0.001
# State |100111010> amplitude 0.002
# State |101010000> amplitude 0.003
# State |101011100> amplitude 0.001
# State |101100010> amplitude 0.004
# State |101100100> amplitude 0.001
# State |101100110> amplitude 0.001
# State |101101010> amplitude 0.001
# State |101111110> amplitude 0.001
# State |110001000> amplitude 0.007
# State |110001010> amplitude 0.001
# State |110010001> amplitude 0.002
# State |110010011> amplitude 0.001
# State |110011001> amplitude 0.002
# State |110011101> amplitude 0.001
# State |110100000> amplitude 0.001
# State |110100100> amplitude 0.002
# State |110101100> amplitude 0.001
# State |110110000> amplitude 0.001
# State |110111000> amplitude 0.002
# State |111000110> amplitude 0.001
# State |111001100> amplitude 0.001
# State |111010010> amplitude 0.001
# State |111010111> amplitude 0.001
# State |111110001> amplitude 0.002
# State |111110010> amplitude 0.001
# State |111111111> amplitude 0.001
# energy :  -14657.71111508194
# State |000000001> amplitude 0.013
# State |000000010> amplitude 0.008
# State |000000100> amplitude 0.008
# State |000000101> amplitude 0.004
# State |000000110> amplitude 0.003
# State |000000111> amplitude 0.001
# State |000001000> amplitude 0.004
# State |000001001> amplitude 0.001
# State |000001010> amplitude 0.009
# State |000001011> amplitude 0.001
# State |000001100> amplitude 0.027
# State |000001101> amplitude 0.001
# State |000001110> amplitude 0.001
# State |000010000> amplitude 0.007
# State |000010001> amplitude 0.037
# State |000010010> amplitude 0.002
# State |000010100> amplitude 0.008
# State |000010101> amplitude 0.003
# State |000011000> amplitude 0.001
# State |000011001> amplitude 0.001
# State |000011010> amplitude 0.001
# State |000011101> amplitude 0.002
# State |000100000> amplitude 0.006
# State |000100001> amplitude 0.012
# State |000100010> amplitude 0.032
# State |000100011> amplitude 0.001
# State |000100100> amplitude 0.004
# State |000100101> amplitude 0.001
# State |000101000> amplitude 0.004
# State |000101001> amplitude 0.001
# State |000101100> amplitude 0.002
# State |000101110> amplitude 0.001
# State |000110000> amplitude 0.006
# State |000110001> amplitude 0.001
# State |000110010> amplitude 0.001
# State |001000000> amplitude 0.006
# State |001000001> amplitude 0.005
# State |001000010> amplitude 0.032
# State |001000100> amplitude 0.026
# State |001000110> amplitude 0.001
# State |001001000> amplitude 0.002
# State |001001001> amplitude 0.001
# State |001001011> amplitude 0.001
# State |001001100> amplitude 0.003
# State |001010000> amplitude 0.01
# State |001010001> amplitude 0.005
# State |001010100> amplitude 0.007
# State |001010101> amplitude 0.001
# State |001010110> amplitude 0.001
# State |001100000> amplitude 0.033
# State |001100001> amplitude 0.004
# State |001100010> amplitude 0.056
# State |001100100> amplitude 0.005
# State |001100101> amplitude 0.001
# State |001100110> amplitude 0.003
# State |001101000> amplitude 0.002
# State |001101010> amplitude 0.001
# State |001101100> amplitude 0.004
# State |001101101> amplitude 0.001
# State |001101110> amplitude 0.001
# State |001101111> amplitude 0.001
# State |001110000> amplitude 0.001
# State |001110010> amplitude 0.005
# State |001110110> amplitude 0.002
# State |001111111> amplitude 0.001
# State |010000000> amplitude 0.006
# State |010000001> amplitude 0.041
# State |010000010> amplitude 0.003
# State |010000011> amplitude 0.001
# State |010000100> amplitude 0.031
# State |010000101> amplitude 0.004
# State |010001000> amplitude 0.04
# State |010001001> amplitude 0.005
# State |010001010> amplitude 0.002
# State |010001100> amplitude 0.052
# State |010001101> amplitude 0.001
# State |010010000> amplitude 0.001
# State |010010001> amplitude 0.011
# State |010010010> amplitude 0.001
# State |010010100> amplitude 0.002
# State |010011000> amplitude 0.001
# State |010011001> amplitude 0.005
# State |010011101> amplitude 0.001
# State |010011111> amplitude 0.001
# State |010100000> amplitude 0.004
# State |010100001> amplitude 0.008
# State |010100010> amplitude 0.003
# State |010100100> amplitude 0.002
# State |010101000> amplitude 0.003
# State |010101001> amplitude 0.002
# State |010101101> amplitude 0.001
# State |010101110> amplitude 0.002
# State |010111100> amplitude 0.001
# State |011000000> amplitude 0.008
# State |011000100> amplitude 0.006
# State |011000101> amplitude 0.001
# State |011001010> amplitude 0.001
# State |011001100> amplitude 0.001
# State |011010001> amplitude 0.001
# State |011010010> amplitude 0.001
# State |011010100> amplitude 0.003
# State |011100000> amplitude 0.002
# State |011100010> amplitude 0.001
# State |011100110> amplitude 0.002
# State |011101000> amplitude 0.003
# State |011101010> amplitude 0.001
# State |011101100> amplitude 0.003
# State |011101110> amplitude 0.004
# State |011110000> amplitude 0.001
# State |100000000> amplitude 0.011
# State |100000001> amplitude 0.022
# State |100000010> amplitude 0.034
# State |100000011> amplitude 0.004
# State |100000100> amplitude 0.004
# State |100000110> amplitude 0.001
# State |100001000> amplitude 0.006
# State |100001010> amplitude 0.009
# State |100001100> amplitude 0.002
# State |100010000> amplitude 0.035
# State |100010001> amplitude 0.063
# State |100010010> amplitude 0.006
# State |100010011> amplitude 0.002
# State |100010100> amplitude 0.004
# State |100011000> amplitude 0.002
# State |100011010> amplitude 0.001
# State |100100000> amplitude 0.007
# State |100100001> amplitude 0.001
# State |100100010> amplitude 0.008
# State |100100100> amplitude 0.001
# State |100101010> amplitude 0.001
# State |100101110> amplitude 0.001
# State |100110000> amplitude 0.001
# State |100110001> amplitude 0.001
# State |100110010> amplitude 0.004
# State |100110011> amplitude 0.002
# State |100111001> amplitude 0.001
# State |101000000> amplitude 0.009
# State |101000010> amplitude 0.006
# State |101000011> amplitude 0.001
# State |101000100> amplitude 0.001
# State |101100010> amplitude 0.002
# State |101101011> amplitude 0.001
# State |101110000> amplitude 0.001
# State |101110001> amplitude 0.001
# State |101110100> amplitude 0.001
# State |101111100> amplitude 0.001
# State |110000000> amplitude 0.005
# State |110000001> amplitude 0.001
# State |110000101> amplitude 0.001
# State |110001000> amplitude 0.005
# State |110010001> amplitude 0.005
# State |110011000> amplitude 0.002
# State |110011001> amplitude 0.001
# State |110011101> amplitude 0.004
# State |110100001> amplitude 0.002
# State |110110001> amplitude 0.001
# State |110111110> amplitude 0.001
# State |111000000> amplitude 0.001
# State |111000001> amplitude 0.001
# State |111111001> amplitude 0.001
# energy :  -16514.15104024764
# State |000000000> amplitude 0.049
# State |000000001> amplitude 0.012
# State |000000010> amplitude 0.008
# State |000000100> amplitude 0.009
# State |000000101> amplitude 0.001
# State |000001000> amplitude 0.013
# State |000001010> amplitude 0.011
# State |000001100> amplitude 0.022
# State |000001110> amplitude 0.007
# State |000001111> amplitude 0.001
# State |000010000> amplitude 0.016
# State |000010001> amplitude 0.019
# State |000010010> amplitude 0.001
# State |000010100> amplitude 0.013
# State |000010101> amplitude 0.003
# State |000011000> amplitude 0.002
# State |000011001> amplitude 0.001
# State |000011010> amplitude 0.001
# State |000011100> amplitude 0.005
# State |000011101> amplitude 0.001
# State |000100000> amplitude 0.006
# State |000100001> amplitude 0.02
# State |000100010> amplitude 0.021
# State |000100011> amplitude 0.009
# State |000100111> amplitude 0.001
# State |000101010> amplitude 0.003
# State |000101011> amplitude 0.001
# State |000101100> amplitude 0.001
# State |000101110> amplitude 0.001
# State |000110000> amplitude 0.007
# State |000110001> amplitude 0.005
# State |000110010> amplitude 0.001
# State |000110100> amplitude 0.002
# State |000110101> amplitude 0.002
# State |000111001> amplitude 0.001
# State |001000000> amplitude 0.007
# State |001000001> amplitude 0.008
# State |001000010> amplitude 0.04
# State |001000100> amplitude 0.019
# State |001001100> amplitude 0.003
# State |001001110> amplitude 0.002
# State |001010000> amplitude 0.016
# State |001010001> amplitude 0.002
# State |001010011> amplitude 0.001
# State |001010100> amplitude 0.067
# State |001010110> amplitude 0.003
# State |001010111> amplitude 0.001
# State |001011000> amplitude 0.002
# State |001100000> amplitude 0.017
# State |001100001> amplitude 0.004
# State |001100010> amplitude 0.001
# State |001100011> amplitude 0.004
# State |001100100> amplitude 0.001
# State |001101101> amplitude 0.001
# State |001110000> amplitude 0.004
# State |001110001> amplitude 0.005
# State |001110100> amplitude 0.001
# State |001110110> amplitude 0.001
# State |001111010> amplitude 0.001
# State |001111101> amplitude 0.001
# State |010000000> amplitude 0.009
# State |010000001> amplitude 0.013
# State |010000010> amplitude 0.008
# State |010000100> amplitude 0.032
# State |010000110> amplitude 0.001
# State |010001000> amplitude 0.016
# State |010001001> amplitude 0.002
# State |010001010> amplitude 0.004
# State |010001100> amplitude 0.001
# State |010001110> amplitude 0.002
# State |010010001> amplitude 0.005
# State |010010100> amplitude 0.001
# State |010010101> amplitude 0.003
# State |010011000> amplitude 0.002
# State |010011110> amplitude 0.001
# State |010100000> amplitude 0.016
# State |010100001> amplitude 0.079
# State |010100010> amplitude 0.005
# State |010100100> amplitude 0.001
# State |010101000> amplitude 0.003
# State |010101001> amplitude 0.001
# State |010101010> amplitude 0.01
# State |010110000> amplitude 0.001
# State |010110110> amplitude 0.001
# State |011000000> amplitude 0.005
# State |011000100> amplitude 0.002
# State |011001000> amplitude 0.001
# State |011001101> amplitude 0.002
# State |011001111> amplitude 0.001
# State |011011110> amplitude 0.001
# State |011100000> amplitude 0.006
# State |011100100> amplitude 0.001
# State |011100101> amplitude 0.001
# State |011101111> amplitude 0.001
# State |011110000> amplitude 0.001
# State |011110001> amplitude 0.001
# State |011110010> amplitude 0.001
# State |100000000> amplitude 0.016
# State |100000001> amplitude 0.044
# State |100000010> amplitude 0.013
# State |100000100> amplitude 0.006
# State |100001000> amplitude 0.021
# State |100001001> amplitude 0.003
# State |100001010> amplitude 0.076
# State |100001011> amplitude 0.001
# State |100001100> amplitude 0.002
# State |100010000> amplitude 0.01
# State |100010100> amplitude 0.004
# State |100010101> amplitude 0.004
# State |100011000> amplitude 0.006
# State |100011100> amplitude 0.006
# State |100011110> amplitude 0.001
# State |100100001> amplitude 0.001
# State |100100010> amplitude 0.002
# State |100100011> amplitude 0.001
# State |100101000> amplitude 0.003
# State |101000000> amplitude 0.002
# State |101001010> amplitude 0.001
# State |101010000> amplitude 0.009
# State |101010001> amplitude 0.003
# State |101011010> amplitude 0.001
# State |101011100> amplitude 0.001
# State |101100101> amplitude 0.001
# State |101101000> amplitude 0.001
# State |101110000> amplitude 0.002
# State |101110110> amplitude 0.001
# State |110000000> amplitude 0.001
# State |110000001> amplitude 0.003
# State |110001000> amplitude 0.008
# State |110001100> amplitude 0.003
# State |110011000> amplitude 0.001
# State |110100001> amplitude 0.001
# State |110100100> amplitude 0.001
# State |110101000> amplitude 0.002
# State |110101010> amplitude 0.001
# State |110110000> amplitude 0.001
# State |110111000> amplitude 0.001
# State |110111010> amplitude 0.001
# State |110111100> amplitude 0.001
# State |111000111> amplitude 0.001
# State |111010000> amplitude 0.001
# State |111010110> amplitude 0.001
# State |111100001> amplitude 0.001
# energy :  -16343.094249054018
# State |000000000> amplitude 0.029
# State |000000001> amplitude 0.018
# State |000000010> amplitude 0.025
# State |000000100> amplitude 0.018
# State |000001000> amplitude 0.003
# State |000001001> amplitude 0.005
# State |000001010> amplitude 0.005
# State |000001100> amplitude 0.019
# State |000001101> amplitude 0.001
# State |000001110> amplitude 0.003
# State |000010000> amplitude 0.001
# State |000010001> amplitude 0.025
# State |000010100> amplitude 0.001
# State |000010101> amplitude 0.002
# State |000011000> amplitude 0.005
# State |000011100> amplitude 0.003
# State |000100000> amplitude 0.004
# State |000100001> amplitude 0.002
# State |000100010> amplitude 0.024
# State |000100011> amplitude 0.004
# State |000100100> amplitude 0.005
# State |000100110> amplitude 0.001
# State |000100111> amplitude 0.001
# State |000101000> amplitude 0.001
# State |000101011> amplitude 0.001
# State |000101100> amplitude 0.002
# State |000110000> amplitude 0.004
# State |000110111> amplitude 0.001
# State |001000000> amplitude 0.023
# State |001000010> amplitude 0.058
# State |001000100> amplitude 0.039
# State |001000110> amplitude 0.002
# State |001001000> amplitude 0.002
# State |001001010> amplitude 0.003
# State |001001100> amplitude 0.003
# State |001010000> amplitude 0.003
# State |001010001> amplitude 0.002
# State |001010010> amplitude 0.002
# State |001010100> amplitude 0.019
# State |001010101> amplitude 0.001
# State |001011001> amplitude 0.001
# State |001100000> amplitude 0.024
# State |001100001> amplitude 0.004
# State |001100010> amplitude 0.037
# State |001100011> amplitude 0.001
# State |001100100> amplitude 0.004
# State |001101010> amplitude 0.003
# State |001101100> amplitude 0.003
# State |001101111> amplitude 0.001
# State |001110000> amplitude 0.002
# State |001110001> amplitude 0.003
# State |001110010> amplitude 0.002
# State |001110100> amplitude 0.002
# State |001111010> amplitude 0.001
# State |010000000> amplitude 0.019
# State |010000001> amplitude 0.031
# State |010000100> amplitude 0.057
# State |010000101> amplitude 0.002
# State |010001000> amplitude 0.025
# State |010001001> amplitude 0.004
# State |010001010> amplitude 0.001
# State |010001011> amplitude 0.001
# State |010001100> amplitude 0.033
# State |010001101> amplitude 0.001
# State |010001110> amplitude 0.006
# State |010010000> amplitude 0.006
# State |010010001> amplitude 0.005
# State |010010010> amplitude 0.001
# State |010010100> amplitude 0.001
# State |010011000> amplitude 0.001
# State |010011101> amplitude 0.001
# State |010100000> amplitude 0.002
# State |010100001> amplitude 0.024
# State |010100010> amplitude 0.003
# State |010100011> amplitude 0.001
# State |010100101> amplitude 0.001
# State |010101000> amplitude 0.001
# State |010101010> amplitude 0.006
# State |010101100> amplitude 0.002
# State |010101101> amplitude 0.001
# State |010101110> amplitude 0.001
# State |010110001> amplitude 0.001
# State |010111010> amplitude 0.001
# State |011000100> amplitude 0.002
# State |011001100> amplitude 0.002
# State |011001101> amplitude 0.001
# State |011010000> amplitude 0.001
# State |011010001> amplitude 0.001
# State |011100000> amplitude 0.006
# State |011100001> amplitude 0.001
# State |011100010> amplitude 0.004
# State |011101100> amplitude 0.001
# State |011101101> amplitude 0.001
# State |100000000> amplitude 0.012
# State |100000001> amplitude 0.066
# State |100000010> amplitude 0.047
# State |100000011> amplitude 0.002
# State |100001000> amplitude 0.003
# State |100001001> amplitude 0.003
# State |100001010> amplitude 0.006
# State |100001100> amplitude 0.002
# State |100010000> amplitude 0.02
# State |100010001> amplitude 0.04
# State |100010010> amplitude 0.005
# State |100010011> amplitude 0.004
# State |100010100> amplitude 0.005
# State |100010101> amplitude 0.002
# State |100011000> amplitude 0.001
# State |100011001> amplitude 0.005
# State |100011100> amplitude 0.003
# State |100100000> amplitude 0.002
# State |100100001> amplitude 0.002
# State |100100010> amplitude 0.001
# State |100100101> amplitude 0.001
# State |100101000> amplitude 0.001
# State |100110000> amplitude 0.001
# State |100110010> amplitude 0.002
# State |100110011> amplitude 0.001
# State |100111001> amplitude 0.001
# State |100111011> amplitude 0.001
# State |100111101> amplitude 0.001
# State |101000010> amplitude 0.002
# State |101000110> amplitude 0.001
# State |101001000> amplitude 0.001
# State |101010000> amplitude 0.003
# State |101010001> amplitude 0.004
# State |101011000> amplitude 0.001
# State |101011001> amplitude 0.001
# State |101100000> amplitude 0.001
# State |101100010> amplitude 0.001
# State |101100110> amplitude 0.002
# State |101101000> amplitude 0.001
# State |110000000> amplitude 0.001
# State |110000001> amplitude 0.003
# State |110001000> amplitude 0.002
# State |110001010> amplitude 0.003
# State |110001100> amplitude 0.004
# State |110001110> amplitude 0.002
# State |110011001> amplitude 0.001
# State |110011100> amplitude 0.001
# State |110011111> amplitude 0.001
# State |110101000> amplitude 0.001
# State |110101110> amplitude 0.001
# State |110110000> amplitude 0.001
# State |111001010> amplitude 0.001
# State |111011011> amplitude 0.001
# State |111100001> amplitude 0.001
# State |111101100> amplitude 0.001
# energy :  22745.656259911928
# State |000000000> amplitude 0.037
# State |000000001> amplitude 0.008
# State |000000010> amplitude 0.012
# State |000000100> amplitude 0.009
# State |000000111> amplitude 0.006
# State |000001000> amplitude 0.009
# State |000001001> amplitude 0.002
# State |000001011> amplitude 0.004
# State |000001100> amplitude 0.006
# State |000001101> amplitude 0.002
# State |000001110> amplitude 0.006
# State |000010000> amplitude 0.008
# State |000010001> amplitude 0.006
# State |000010010> amplitude 0.004
# State |000010011> amplitude 0.001
# State |000010100> amplitude 0.001
# State |000010101> amplitude 0.006
# State |000011000> amplitude 0.011
# State |000011001> amplitude 0.001
# State |000011010> amplitude 0.003
# State |000011100> amplitude 0.005
# State |000011101> amplitude 0.001
# State |000011110> amplitude 0.001
# State |000100000> amplitude 0.005
# State |000100001> amplitude 0.001
# State |000100010> amplitude 0.009
# State |000100011> amplitude 0.003
# State |000100100> amplitude 0.004
# State |000100111> amplitude 0.001
# State |000101000> amplitude 0.013
# State |000101001> amplitude 0.001
# State |000101010> amplitude 0.008
# State |000101011> amplitude 0.002
# State |000101100> amplitude 0.001
# State |000101101> amplitude 0.006
# State |000101111> amplitude 0.002
# State |000110000> amplitude 0.011
# State |000110001> amplitude 0.005
# State |000110010> amplitude 0.005
# State |000110011> amplitude 0.001
# State |000110100> amplitude 0.003
# State |000110101> amplitude 0.001
# State |000110110> amplitude 0.004
# State |000111000> amplitude 0.015
# State |000111011> amplitude 0.001
# State |000111100> amplitude 0.001
# State |000111101> amplitude 0.002
# State |000111110> amplitude 0.002
# State |001000000> amplitude 0.006
# State |001000001> amplitude 0.001
# State |001000010> amplitude 0.002
# State |001000011> amplitude 0.002
# State |001000100> amplitude 0.018
# State |001000110> amplitude 0.002
# State |001000111> amplitude 0.005
# State |001001000> amplitude 0.004
# State |001001001> amplitude 0.002
# State |001001101> amplitude 0.001
# State |001001110> amplitude 0.009
# State |001010000> amplitude 0.001
# State |001010010> amplitude 0.001
# State |001010011> amplitude 0.001
# State |001010100> amplitude 0.003
# State |001010101> amplitude 0.001
# State |001010110> amplitude 0.002
# State |001010111> amplitude 0.001
# State |001011000> amplitude 0.001
# State |001011001> amplitude 0.002
# State |001011010> amplitude 0.001
# State |001011100> amplitude 0.001
# State |001100000> amplitude 0.002
# State |001100010> amplitude 0.006
# State |001100011> amplitude 0.007
# State |001100100> amplitude 0.001
# State |001100110> amplitude 0.005
# State |001100111> amplitude 0.004
# State |001101000> amplitude 0.005
# State |001101011> amplitude 0.003
# State |001101110> amplitude 0.002
# State |001101111> amplitude 0.004
# State |001110000> amplitude 0.004
# State |001110001> amplitude 0.009
# State |001110010> amplitude 0.001
# State |001110011> amplitude 0.002
# State |001110101> amplitude 0.001
# State |001110111> amplitude 0.002
# State |001111001> amplitude 0.003
# State |001111010> amplitude 0.002
# State |001111011> amplitude 0.001
# State |001111100> amplitude 0.002
# State |001111101> amplitude 0.002
# State |001111110> amplitude 0.001
# State |010000000> amplitude 0.01
# State |010000001> amplitude 0.026
# State |010000010> amplitude 0.001
# State |010000011> amplitude 0.001
# State |010000100> amplitude 0.001
# State |010000111> amplitude 0.004
# State |010001000> amplitude 0.006
# State |010001100> amplitude 0.007
# State |010001101> amplitude 0.002
# State |010001110> amplitude 0.003
# State |010010000> amplitude 0.002
# State |010010001> amplitude 0.001
# State |010010010> amplitude 0.001
# State |010010101> amplitude 0.007
# State |010011000> amplitude 0.002
# State |010011010> amplitude 0.002
# State |010011101> amplitude 0.002
# State |010011110> amplitude 0.003
# State |010011111> amplitude 0.003
# State |010100000> amplitude 0.002
# State |010100001> amplitude 0.009
# State |010100011> amplitude 0.002
# State |010100101> amplitude 0.002
# State |010100110> amplitude 0.002
# State |010100111> amplitude 0.002
# State |010101000> amplitude 0.004
# State |010101001> amplitude 0.001
# State |010101010> amplitude 0.006
# State |010101011> amplitude 0.001
# State |010101101> amplitude 0.005
# State |010101110> amplitude 0.006
# State |010110001> amplitude 0.001
# State |010110010> amplitude 0.001
# State |010110100> amplitude 0.002
# State |010110110> amplitude 0.002
# State |010111011> amplitude 0.002
# State |010111100> amplitude 0.001
# State |010111101> amplitude 0.001
# State |010111110> amplitude 0.001
# State |011000011> amplitude 0.002
# State |011000100> amplitude 0.001
# State |011000101> amplitude 0.009
# State |011000110> amplitude 0.002
# State |011001000> amplitude 0.001
# State |011001010> amplitude 0.001
# State |011001100> amplitude 0.001
# State |011001101> amplitude 0.005
# State |011001110> amplitude 0.003
# State |011010000> amplitude 0.001
# State |011010100> amplitude 0.001
# State |011010110> amplitude 0.001
# State |011010111> amplitude 0.001
# State |011011000> amplitude 0.001
# State |011011001> amplitude 0.003
# State |011011011> amplitude 0.001
# State |011100000> amplitude 0.006
# State |011100001> amplitude 0.001
# State |011100010> amplitude 0.004
# State |011100011> amplitude 0.004
# State |011100100> amplitude 0.01
# State |011100101> amplitude 0.001
# State |011100110> amplitude 0.004
# State |011100111> amplitude 0.002
# State |011101010> amplitude 0.001
# State |011101100> amplitude 0.002
# State |011101110> amplitude 0.001
# State |011101111> amplitude 0.001
# State |011110000> amplitude 0.002
# State |011110001> amplitude 0.002
# State |011110010> amplitude 0.001
# State |011111000> amplitude 0.003
# State |011111101> amplitude 0.002
# State |011111110> amplitude 0.002
# State |100000000> amplitude 0.011
# State |100000001> amplitude 0.005
# State |100000010> amplitude 0.037
# State |100000011> amplitude 0.001
# State |100000100> amplitude 0.001
# State |100000101> amplitude 0.001
# State |100000111> amplitude 0.004
# State |100001001> amplitude 0.001
# State |100001010> amplitude 0.003
# State |100001101> amplitude 0.002
# State |100001110> amplitude 0.002
# State |100001111> amplitude 0.001
# State |100010000> amplitude 0.004
# State |100010001> amplitude 0.005
# State |100010010> amplitude 0.001
# State |100010011> amplitude 0.002
# State |100010101> amplitude 0.006
# State |100010111> amplitude 0.003
# State |100011000> amplitude 0.004
# State |100011001> amplitude 0.001
# State |100011011> amplitude 0.003
# State |100011100> amplitude 0.003
# State |100100000> amplitude 0.001
# State |100100010> amplitude 0.002
# State |100100011> amplitude 0.01
# State |100100100> amplitude 0.003
# State |100100111> amplitude 0.001
# State |100101000> amplitude 0.003
# State |100101100> amplitude 0.002
# State |100110010> amplitude 0.001
# State |100110011> amplitude 0.002
# State |100110100> amplitude 0.004
# State |100110101> amplitude 0.001
# State |100110111> amplitude 0.002
# State |100111001> amplitude 0.003
# State |100111010> amplitude 0.002
# State |100111101> amplitude 0.001
# State |100111110> amplitude 0.001
# State |100111111> amplitude 0.001
# State |101000000> amplitude 0.001
# State |101000001> amplitude 0.001
# State |101000010> amplitude 0.001
# State |101000011> amplitude 0.002
# State |101000101> amplitude 0.001
# State |101000110> amplitude 0.006
# State |101001000> amplitude 0.002
# State |101001111> amplitude 0.001
# State |101010000> amplitude 0.006
# State |101010001> amplitude 0.003
# State |101010010> amplitude 0.006
# State |101010011> amplitude 0.007
# State |101010100> amplitude 0.002
# State |101010101> amplitude 0.003
# State |101010110> amplitude 0.002
# State |101010111> amplitude 0.002
# State |101011000> amplitude 0.002
# State |101011001> amplitude 0.002
# State |101011010> amplitude 0.002
# State |101011011> amplitude 0.002
# State |101011100> amplitude 0.002
# State |101011101> amplitude 0.001
# State |101011110> amplitude 0.002
# State |101011111> amplitude 0.002
# State |101100000> amplitude 0.001
# State |101100001> amplitude 0.003
# State |101100010> amplitude 0.001
# State |101100110> amplitude 0.001
# State |101100111> amplitude 0.003
# State |101101000> amplitude 0.003
# State |101101001> amplitude 0.002
# State |101101010> amplitude 0.007
# State |101101100> amplitude 0.001
# State |101101101> amplitude 0.002
# State |101110001> amplitude 0.003
# State |101110010> amplitude 0.003
# State |101110101> amplitude 0.001
# State |101110111> amplitude 0.001
# State |101111001> amplitude 0.001
# State |101111011> amplitude 0.002
# State |101111100> amplitude 0.001
# State |101111110> amplitude 0.003
# State |110000010> amplitude 0.001
# State |110000011> amplitude 0.002
# State |110000110> amplitude 0.006
# State |110001000> amplitude 0.003
# State |110001001> amplitude 0.003
# State |110001010> amplitude 0.002
# State |110001011> amplitude 0.001
# State |110001100> amplitude 0.003
# State |110001101> amplitude 0.003
# State |110001110> amplitude 0.001
# State |110001111> amplitude 0.001
# State |110010001> amplitude 0.004
# State |110010011> amplitude 0.003
# State |110010100> amplitude 0.001
# State |110010101> amplitude 0.001
# State |110011001> amplitude 0.001
# State |110011010> amplitude 0.001
# State |110011100> amplitude 0.001
# State |110011110> amplitude 0.002
# State |110100000> amplitude 0.003
# State |110100001> amplitude 0.001
# State |110100011> amplitude 0.002
# State |110100100> amplitude 0.002
# State |110100110> amplitude 0.001
# State |110100111> amplitude 0.003
# State |110101000> amplitude 0.004
# State |110101001> amplitude 0.003
# State |110101010> amplitude 0.001
# State |110101011> amplitude 0.002
# State |110101100> amplitude 0.001
# State |110101101> amplitude 0.001
# State |110101110> amplitude 0.001
# State |110101111> amplitude 0.002
# State |110110000> amplitude 0.001
# State |110110001> amplitude 0.004
# State |110110010> amplitude 0.002
# State |110110011> amplitude 0.001
# State |110110100> amplitude 0.001
# State |110110101> amplitude 0.001
# State |110111001> amplitude 0.002
# State |110111010> amplitude 0.001
# State |110111011> amplitude 0.001
# State |110111101> amplitude 0.001
# State |111000000> amplitude 0.002
# State |111000001> amplitude 0.004
# State |111000010> amplitude 0.002
# State |111000100> amplitude 0.004
# State |111000111> amplitude 0.002
# State |111001000> amplitude 0.001
# State |111001010> amplitude 0.001
# State |111001011> amplitude 0.001
# State |111001100> amplitude 0.002
# State |111001110> amplitude 0.003
# State |111010000> amplitude 0.001
# State |111010001> amplitude 0.002
# State |111010011> amplitude 0.001
# State |111010100> amplitude 0.001
# State |111010101> amplitude 0.002
# State |111010110> amplitude 0.002
# State |111010111> amplitude 0.001
# State |111011001> amplitude 0.002
# State |111011100> amplitude 0.001
# State |111011110> amplitude 0.004
# State |111100010> amplitude 0.001
# State |111100011> amplitude 0.003
# State |111100100> amplitude 0.001
# State |111100101> amplitude 0.002
# State |111100110> amplitude 0.001
# State |111100111> amplitude 0.002
# State |111101001> amplitude 0.001
# State |111101010> amplitude 0.002
# State |111101011> amplitude 0.002
# State |111101100> amplitude 0.003
# State |111110000> amplitude 0.001
# State |111110001> amplitude 0.002
# State |111110010> amplitude 0.003
# State |111111011> amplitude 0.001
# State |111111101> amplitude 0.001
# energy :  21425.838346100194
# State |000000000> amplitude 0.042
# State |000000001> amplitude 0.002
# State |000000110> amplitude 0.001
# State |000001000> amplitude 0.002
# State |000001001> amplitude 0.001
# State |000001010> amplitude 0.001
# State |000001011> amplitude 0.002
# State |000001111> amplitude 0.002
# State |000010000> amplitude 0.001
# State |000010010> amplitude 0.003
# State |000010100> amplitude 0.001
# State |000010110> amplitude 0.001
# State |000011000> amplitude 0.004
# State |000011001> amplitude 0.009
# State |000011100> amplitude 0.001
# State |000100000> amplitude 0.005
# State |000100001> amplitude 0.001
# State |000100100> amplitude 0.004
# State |000100101> amplitude 0.006
# State |000100110> amplitude 0.001
# State |000100111> amplitude 0.001
# State |000101000> amplitude 0.002
# State |000101010> amplitude 0.004
# State |000101100> amplitude 0.007
# State |000101101> amplitude 0.001
# State |000101111> amplitude 0.001
# State |000110001> amplitude 0.002
# State |000110010> amplitude 0.009
# State |000110011> amplitude 0.001
# State |000110100> amplitude 0.001
# State |000110110> amplitude 0.002
# State |000110111> amplitude 0.001
# State |000111000> amplitude 0.012
# State |000111010> amplitude 0.001
# State |000111111> amplitude 0.001
# State |001000001> amplitude 0.004
# State |001000010> amplitude 0.002
# State |001000100> amplitude 0.006
# State |001000101> amplitude 0.007
# State |001000110> amplitude 0.008
# State |001000111> amplitude 0.001
# State |001001000> amplitude 0.004
# State |001001001> amplitude 0.019
# State |001001010> amplitude 0.009
# State |001001011> amplitude 0.002
# State |001001100> amplitude 0.003
# State |001001110> amplitude 0.001
# State |001001111> amplitude 0.003
# State |001010001> amplitude 0.003
# State |001010010> amplitude 0.008
# State |001010011> amplitude 0.001
# State |001010100> amplitude 0.001
# State |001010101> amplitude 0.003
# State |001011000> amplitude 0.001
# State |001011001> amplitude 0.005
# State |001011010> amplitude 0.002
# State |001011111> amplitude 0.001
# State |001100001> amplitude 0.002
# State |001100010> amplitude 0.039
# State |001100100> amplitude 0.003
# State |001100110> amplitude 0.002
# State |001101000> amplitude 0.008
# State |001101001> amplitude 0.004
# State |001101010> amplitude 0.001
# State |001101011> amplitude 0.003
# State |001101100> amplitude 0.007
# State |001110000> amplitude 0.001
# State |001110001> amplitude 0.004
# State |001110010> amplitude 0.001
# State |001110100> amplitude 0.001
# State |001110110> amplitude 0.007
# State |001111000> amplitude 0.001
# State |001111001> amplitude 0.003
# State |001111010> amplitude 0.005
# State |001111101> amplitude 0.002
# State |010000001> amplitude 0.004
# State |010000010> amplitude 0.006
# State |010000011> amplitude 0.002
# State |010000100> amplitude 0.002
# State |010000101> amplitude 0.007
# State |010000111> amplitude 0.003
# State |010001000> amplitude 0.001
# State |010001001> amplitude 0.003
# State |010001010> amplitude 0.001
# State |010001011> amplitude 0.001
# State |010001100> amplitude 0.037
# State |010001101> amplitude 0.001
# State |010010000> amplitude 0.001
# State |010010001> amplitude 0.004
# State |010010010> amplitude 0.021
# State |010010100> amplitude 0.01
# State |010010110> amplitude 0.002
# State |010010111> amplitude 0.003
# State |010011000> amplitude 0.002
# State |010011001> amplitude 0.004
# State |010011010> amplitude 0.004
# State |010011100> amplitude 0.001
# State |010011101> amplitude 0.002
# State |010011110> amplitude 0.002
# State |010100001> amplitude 0.004
# State |010100010> amplitude 0.008
# State |010100011> amplitude 0.002
# State |010100100> amplitude 0.013
# State |010100101> amplitude 0.004
# State |010100110> amplitude 0.001
# State |010101000> amplitude 0.006
# State |010101010> amplitude 0.002
# State |010101101> amplitude 0.01
# State |010101111> amplitude 0.001
# State |010110000> amplitude 0.001
# State |010110001> amplitude 0.001
# State |010110010> amplitude 0.003
# State |010110100> amplitude 0.002
# State |010111000> amplitude 0.001
# State |010111010> amplitude 0.001
# State |010111011> amplitude 0.002
# State |010111100> amplitude 0.002
# State |010111101> amplitude 0.002
# State |010111110> amplitude 0.001
# State |011000001> amplitude 0.003
# State |011000011> amplitude 0.008
# State |011000100> amplitude 0.004
# State |011000101> amplitude 0.001
# State |011000110> amplitude 0.008
# State |011001011> amplitude 0.001
# State |011001100> amplitude 0.001
# State |011001101> amplitude 0.001
# State |011001110> amplitude 0.004
# State |011001111> amplitude 0.002
# State |011010000> amplitude 0.003
# State |011010001> amplitude 0.003
# State |011010010> amplitude 0.001
# State |011010011> amplitude 0.001
# State |011010100> amplitude 0.003
# State |011010110> amplitude 0.001
# State |011011000> amplitude 0.001
# State |011011011> amplitude 0.001
# State |011011100> amplitude 0.009
# State |011011101> amplitude 0.002
# State |011011111> amplitude 0.001
# State |011100001> amplitude 0.001
# State |011100010> amplitude 0.001
# State |011100100> amplitude 0.002
# State |011100110> amplitude 0.004
# State |011101000> amplitude 0.001
# State |011101100> amplitude 0.001
# State |011101110> amplitude 0.001
# State |011110010> amplitude 0.002
# State |011111001> amplitude 0.001
# State |011111010> amplitude 0.001
# State |011111100> amplitude 0.001
# State |100000000> amplitude 0.004
# State |100000001> amplitude 0.004
# State |100000010> amplitude 0.003
# State |100000011> amplitude 0.005
# State |100000100> amplitude 0.005
# State |100000110> amplitude 0.006
# State |100001001> amplitude 0.007
# State |100001010> amplitude 0.001
# State |100001011> amplitude 0.003
# State |100001100> amplitude 0.001
# State |100001101> amplitude 0.001
# State |100001110> amplitude 0.001
# State |100001111> amplitude 0.002
# State |100010001> amplitude 0.034
# State |100010010> amplitude 0.001
# State |100010101> amplitude 0.004
# State |100010110> amplitude 0.002
# State |100011000> amplitude 0.004
# State |100011001> amplitude 0.001
# State |100011011> amplitude 0.009
# State |100011100> amplitude 0.003
# State |100011110> amplitude 0.001
# State |100100000> amplitude 0.002
# State |100100001> amplitude 0.01
# State |100100010> amplitude 0.008
# State |100100011> amplitude 0.002
# State |100100100> amplitude 0.016
# State |100100111> amplitude 0.001
# State |100101000> amplitude 0.003
# State |100101001> amplitude 0.003
# State |100101010> amplitude 0.001
# State |100101100> amplitude 0.003
# State |100101111> amplitude 0.001
# State |100110000> amplitude 0.003
# State |100110001> amplitude 0.001
# State |100110010> amplitude 0.007
# State |100110011> amplitude 0.002
# State |100110100> amplitude 0.007
# State |100110101> amplitude 0.001
# State |100110110> amplitude 0.001
# State |100110111> amplitude 0.001
# State |100111001> amplitude 0.001
# State |100111010> amplitude 0.003
# State |100111100> amplitude 0.003
# State |101000010> amplitude 0.003
# State |101000011> amplitude 0.009
# State |101000100> amplitude 0.002
# State |101000101> amplitude 0.004
# State |101000110> amplitude 0.002
# State |101001000> amplitude 0.004
# State |101001001> amplitude 0.001
# State |101001010> amplitude 0.003
# State |101001011> amplitude 0.005
# State |101001100> amplitude 0.001
# State |101001110> amplitude 0.001
# State |101010000> amplitude 0.001
# State |101010001> amplitude 0.001
# State |101010010> amplitude 0.002
# State |101010011> amplitude 0.007
# State |101010100> amplitude 0.004
# State |101010111> amplitude 0.001
# State |101011101> amplitude 0.001
# State |101100001> amplitude 0.003
# State |101100010> amplitude 0.002
# State |101100011> amplitude 0.006
# State |101100101> amplitude 0.002
# State |101100111> amplitude 0.002
# State |101101000> amplitude 0.001
# State |101101010> amplitude 0.005
# State |101101011> amplitude 0.001
# State |101101101> amplitude 0.001
# State |101101110> amplitude 0.002
# State |101110010> amplitude 0.002
# State |101110011> amplitude 0.001
# State |101110110> amplitude 0.001
# State |101111001> amplitude 0.001
# State |101111011> amplitude 0.004
# State |101111100> amplitude 0.001
# State |110000001> amplitude 0.008
# State |110000010> amplitude 0.001
# State |110000101> amplitude 0.006
# State |110000110> amplitude 0.008
# State |110001000> amplitude 0.001
# State |110001001> amplitude 0.002
# State |110001010> amplitude 0.003
# State |110001011> amplitude 0.001
# State |110001100> amplitude 0.002
# State |110001101> amplitude 0.005
# State |110001110> amplitude 0.001
# State |110010001> amplitude 0.002
# State |110010010> amplitude 0.001
# State |110010100> amplitude 0.001
# State |110010101> amplitude 0.006
# State |110010110> amplitude 0.001
# State |110011001> amplitude 0.001
# State |110011101> amplitude 0.001
# State |110100000> amplitude 0.007
# State |110100001> amplitude 0.001
# State |110100010> amplitude 0.002
# State |110100011> amplitude 0.001
# State |110100101> amplitude 0.002
# State |110100110> amplitude 0.001
# State |110101100> amplitude 0.005
# State |110110000> amplitude 0.002
# State |110110001> amplitude 0.01
# State |110111001> amplitude 0.001
# State |110111101> amplitude 0.004
# State |111000000> amplitude 0.001
# State |111000001> amplitude 0.001
# State |111000010> amplitude 0.002
# State |111000111> amplitude 0.003
# State |111001000> amplitude 0.005
# State |111001001> amplitude 0.003
# State |111001010> amplitude 0.002
# State |111001011> amplitude 0.002
# State |111001101> amplitude 0.004
# State |111010000> amplitude 0.003
# State |111010010> amplitude 0.001
# State |111010011> amplitude 0.004
# State |111010100> amplitude 0.001
# State |111010111> amplitude 0.001
# State |111011000> amplitude 0.001
# State |111011001> amplitude 0.001
# State |111011100> amplitude 0.001
# State |111100000> amplitude 0.002
# State |111100001> amplitude 0.002
# State |111100100> amplitude 0.004
# State |111100101> amplitude 0.001
# State |111100110> amplitude 0.001
# State |111100111> amplitude 0.002
# State |111101000> amplitude 0.001
# State |111101010> amplitude 0.002
# State |111110000> amplitude 0.002
# State |111111100> amplitude 0.001
# energy :  -19754.58477995664
# State |000000000> amplitude 0.002
# State |000000001> amplitude 0.003
# State |000000010> amplitude 0.013
# State |000000011> amplitude 0.001
# State |000000100> amplitude 0.01
# State |000000101> amplitude 0.004
# State |000001000> amplitude 0.007
# State |000001001> amplitude 0.001
# State |000001010> amplitude 0.009
# State |000001100> amplitude 0.003
# State |000010000> amplitude 0.007
# State |000010001> amplitude 0.003
# State |000010010> amplitude 0.001
# State |000010100> amplitude 0.009
# State |000010101> amplitude 0.001
# State |000011000> amplitude 0.004
# State |000011010> amplitude 0.001
# State |000011100> amplitude 0.002
# State |000100000> amplitude 0.009
# State |000100001> amplitude 0.007
# State |000100010> amplitude 0.002
# State |000100011> amplitude 0.002
# State |000100100> amplitude 0.002
# State |000101000> amplitude 0.005
# State |000101010> amplitude 0.002
# State |000110000> amplitude 0.003
# State |000110001> amplitude 0.001
# State |000110110> amplitude 0.002
# State |000111000> amplitude 0.002
# State |000111111> amplitude 0.001
# State |001000000> amplitude 0.013
# State |001000001> amplitude 0.007
# State |001000010> amplitude 0.025
# State |001000100> amplitude 0.056
# State |001000101> amplitude 0.001
# State |001001000> amplitude 0.001
# State |001001010> amplitude 0.004
# State |001001100> amplitude 0.002
# State |001010000> amplitude 0.014
# State |001010010> amplitude 0.001
# State |001010100> amplitude 0.002
# State |001011001> amplitude 0.001
# State |001100000> amplitude 0.002
# State |001100001> amplitude 0.002
# State |001100010> amplitude 0.124
# State |001100011> amplitude 0.003
# State |001100100> amplitude 0.001
# State |001100110> amplitude 0.001
# State |001110000> amplitude 0.003
# State |001110001> amplitude 0.001
# State |010000000> amplitude 0.016
# State |010000001> amplitude 0.058
# State |010000010> amplitude 0.001
# State |010000100> amplitude 0.046
# State |010000101> amplitude 0.002
# State |010000110> amplitude 0.001
# State |010001000> amplitude 0.006
# State |010001010> amplitude 0.002
# State |010001100> amplitude 0.139
# State |010001101> amplitude 0.001
# State |010001110> amplitude 0.002
# State |010010000> amplitude 0.001
# State |010010001> amplitude 0.005
# State |010010100> amplitude 0.001
# State |010010101> amplitude 0.001
# State |010010111> amplitude 0.001
# State |010011011> amplitude 0.001
# State |010011101> amplitude 0.001
# State |010100000> amplitude 0.003
# State |010100001> amplitude 0.002
# State |010100011> amplitude 0.001
# State |010100100> amplitude 0.004
# State |010100110> amplitude 0.001
# State |010101000> amplitude 0.001
# State |010101001> amplitude 0.001
# State |011000000> amplitude 0.002
# State |011000100> amplitude 0.001
# State |011000110> amplitude 0.001
# State |011000111> amplitude 0.001
# State |011001101> amplitude 0.001
# State |011001110> amplitude 0.005
# State |011010100> amplitude 0.002
# State |011100000> amplitude 0.001
# State |011100111> amplitude 0.001
# State |011101110> amplitude 0.003
# State |011111110> amplitude 0.002
# State |100000000> amplitude 0.009
# State |100000001> amplitude 0.031
# State |100000010> amplitude 0.048
# State |100000011> amplitude 0.003
# State |100000100> amplitude 0.002
# State |100000111> amplitude 0.001
# State |100001000> amplitude 0.007
# State |100001001> amplitude 0.004
# State |100001010> amplitude 0.001
# State |100010000> amplitude 0.004
# State |100010001> amplitude 0.132
# State |100010100> amplitude 0.002
# State |100011000> amplitude 0.001
# State |100100000> amplitude 0.001
# State |100100001> amplitude 0.002
# State |100100010> amplitude 0.003
# State |100100011> amplitude 0.002
# State |100101000> amplitude 0.001
# State |101000001> amplitude 0.003
# State |101000011> amplitude 0.004
# State |101000100> amplitude 0.001
# State |101010000> amplitude 0.002
# State |101010001> amplitude 0.002
# State |101010010> amplitude 0.001
# State |101010011> amplitude 0.001
# State |101100001> amplitude 0.003
# State |101100010> amplitude 0.001
# State |101100110> amplitude 0.002
# State |101110011> amplitude 0.001
# State |101111011> amplitude 0.001
# State |110000000> amplitude 0.003
# State |110000010> amplitude 0.001
# State |110000100> amplitude 0.002
# State |110000101> amplitude 0.002
# State |110001000> amplitude 0.001
# State |110001001> amplitude 0.001
# State |110001010> amplitude 0.001
# State |110001111> amplitude 0.001
# State |110010001> amplitude 0.002
# State |110010100> amplitude 0.001
# State |110010101> amplitude 0.001
# State |110011101> amplitude 0.001
# State |110110000> amplitude 0.001
# State |111000000> amplitude 0.001
# State |111000101> amplitude 0.001
# State |111011001> amplitude 0.001
# State |111100100> amplitude 0.001
# State |111101100> amplitude 0.001
# energy :  -22736.129989159104
# State |000000000> amplitude 0.004
# State |000000001> amplitude 0.009
# State |000000010> amplitude 0.017
# State |000000011> amplitude 0.001
# State |000000100> amplitude 0.012
# State |000001000> amplitude 0.003
# State |000001001> amplitude 0.002
# State |000001100> amplitude 0.009
# State |000001110> amplitude 0.001
# State |000010000> amplitude 0.001
# State |000010001> amplitude 0.005
# State |000010100> amplitude 0.001
# State |000011001> amplitude 0.001
# State |000011100> amplitude 0.003
# State |000100000> amplitude 0.005
# State |000100010> amplitude 0.011
# State |000100011> amplitude 0.001
# State |000100100> amplitude 0.003
# State |000100101> amplitude 0.001
# State |000101010> amplitude 0.003
# State |000110001> amplitude 0.003
# State |000111111> amplitude 0.001
# State |001000000> amplitude 0.007
# State |001000010> amplitude 0.009
# State |001000100> amplitude 0.047
# State |001000111> amplitude 0.001
# State |001001000> amplitude 0.003
# State |001001010> amplitude 0.001
# State |001001100> amplitude 0.008
# State |001010001> amplitude 0.003
# State |001010010> amplitude 0.002
# State |001010100> amplitude 0.004
# State |001011100> amplitude 0.001
# State |001011101> amplitude 0.002
# State |001100000> amplitude 0.012
# State |001100010> amplitude 0.195
# State |001100100> amplitude 0.007
# State |001101110> amplitude 0.001
# State |001110000> amplitude 0.002
# State |001110001> amplitude 0.001
# State |001110010> amplitude 0.001
# State |001111010> amplitude 0.002
# State |010000000> amplitude 0.017
# State |010000001> amplitude 0.03
# State |010000100> amplitude 0.004
# State |010001000> amplitude 0.009
# State |010001001> amplitude 0.004
# State |010001010> amplitude 0.002
# State |010001100> amplitude 0.168
# State |010010000> amplitude 0.003
# State |010010001> amplitude 0.007
# State |010010100> amplitude 0.002
# State |010011000> amplitude 0.001
# State |010011101> amplitude 0.001
# State |010100000> amplitude 0.001
# State |010100001> amplitude 0.005
# State |010100010> amplitude 0.001
# State |010100100> amplitude 0.003
# State |010101000> amplitude 0.002
# State |010101010> amplitude 0.001
# State |010110001> amplitude 0.001
# State |010110111> amplitude 0.001
# State |010111100> amplitude 0.005
# State |011000000> amplitude 0.001
# State |011011110> amplitude 0.001
# State |011100000> amplitude 0.002
# State |011100010> amplitude 0.001
# State |011100110> amplitude 0.001
# State |011101100> amplitude 0.001
# State |011110000> amplitude 0.001
# State |011110100> amplitude 0.001
# State |011111001> amplitude 0.001
# State |100000000> amplitude 0.016
# State |100000001> amplitude 0.004
# State |100000010> amplitude 0.041
# State |100000100> amplitude 0.001
# State |100000101> amplitude 0.001
# State |100001000> amplitude 0.001
# State |100001001> amplitude 0.001
# State |100001010> amplitude 0.006
# State |100001011> amplitude 0.001
# State |100010000> amplitude 0.011
# State |100010001> amplitude 0.182
# State |100010010> amplitude 0.005
# State |100010011> amplitude 0.001
# State |100010100> amplitude 0.002
# State |100011000> amplitude 0.002
# State |100011001> amplitude 0.002
# State |100011010> amplitude 0.001
# State |100100000> amplitude 0.004
# State |100100010> amplitude 0.006
# State |100100110> amplitude 0.003
# State |100101010> amplitude 0.001
# State |100101110> amplitude 0.001
# State |100110001> amplitude 0.001
# State |100110011> amplitude 0.001
# State |100111001> amplitude 0.003
# State |100111010> amplitude 0.001
# State |101001000> amplitude 0.001
# State |101010000> amplitude 0.001
# State |101110110> amplitude 0.001
# State |110000000> amplitude 0.001
# State |110000001> amplitude 0.002
# State |110001110> amplitude 0.001
# State |110010010> amplitude 0.003
# State |110011001> amplitude 0.003
# State |110111100> amplitude 0.002
# State |111010010> amplitude 0.001
# State |111100000> amplitude 0.001

# %%
plt.plot(run_number, energy_QAOA, label='QAOA energy')
plt.plot(run_number, energy_heuristic, label='Heuristic energy')
plt.scatter(run_number, energy_QAOA)
plt.scatter(run_number, energy_heuristic)
plt.plot([0, 9], [-35998, -35998], "--", label = "optimal value")

plt.xlabel('number of layers for standard QAOA')
plt.ylabel('Energy (arbitrary unit)')
plt.title('Converged Energy as a function of the number of layer')
plt.legend(loc='best')
plt.grid()
# Show the plot
plt.show()

# %%
observable = problem.get_observable()
prog = Program()
reg = prog.qalloc(nb_cities**2)
var =  [ prog.new_var(float,'theta'+str(i)) for i in range(nb_cities**2)]
# if we want to add dephasing :
#var2 = [ prog.new_var(float,'phi'+str(i)) for i in range(nb_cities**2)]
# we just apply a RX(theta_i) gate on every qubit
for i in range(nb_cities**2):
    prog.apply(RX(var[i]),reg[i])
    #prog.apply(PH(var2[i]), reg[i])
# From there everything is identical to the QAOA code
circ = prog.to_circ()
job = circ.to_job(observable=observable)
# initialize the optimizer
optimize =ScipyMinimizePlugin(method="BFGS", tol=1e-5, options={"maxiter": 1000}) 
qpu = PyLinalg()
# Once again create the stack
stack =  optimize | qpu 
# get the result
result = stack.submit(job) 
print(result)
print(result.value)
circuit = job.circuit.bind_variables(result.parameter_map) #On récupère le circuit précédent en 
#spécifiant les variables (qui sont celles de l'optimiseur)
job = circuit.to_job(nbshots = 10000) #Le second jo
qpu = PyLinalg()
result = qpu.submit(job) #Résultat des mesures
print(result)
probasRes = np.zeros(2**(nb_cities**2))
for sample in result:
    print( str(sample.state), sample.probability)
# Out:
# Result(need_flip=False, lsb_first=False, nbqbits=None, has_statevector=False, statevector=None, data=None, _value=ComplexNumber(re=-35997.999999999935, im=0.0), raw_data=None, qregs=[QRegister(scope=<qat.lang.AQASM.program.Program object at 0x00000210CED49950>, length=9, start=0, msb=None, _subtype_metadata=None, qbits=[<qat.lang.AQASM.bits.Qbit object at 0x00000210CED49910>, <qat.lang.AQASM.bits.Qbit object at 0x00000210CED48650>, <qat.lang.AQASM.bits.Qbit object at 0x00000210CED4A790>, <qat.lang.AQASM.bits.Qbit object at 0x00000210CED48610>, <qat.lang.AQASM.bits.Qbit object at 0x00000210CED4A350>, <qat.lang.AQASM.bits.Qbit object at 0x00000210CED49590>, <qat.lang.AQASM.bits.Qbit object at 0x00000210CED49CD0>, <qat.lang.AQASM.bits.Qbit object at 0x00000210CED48B50>, <qat.lang.AQASM.bits.Qbit object at 0x00000210BE73C0D0>])], error=None, value_data=None, error_data=None, meta_data={'optimizer_data': '  message: Desired error not necessarily achieved due to precision loss.\n  success: False\n   status: 2\n      fun: -35997.999999999935\n        x: [-3.391e-09 -5.977e-08  3.142e+00 -4.593e-08  9.425e+00\n             6.090e-09  3.142e+00 -1.158e-08 -4.706e-08]\n      nit: 33\n      jac: [ 0.000e+00  0.000e+00  9.766e-04  0.000e+00  9.766e-04\n             9.766e-04  9.766e-04  0.000e+00  4.883e-04]\n hess_inv: [[ 2.727e-05 -1.290e-05 ...  4.364e-08 -1.381e-05]\n            [-1.290e-05  5.744e-05 ...  1.379e-07  7.067e-05]\n            ...\n            [ 4.364e-08  1.379e-07 ...  2.283e-07  6.387e-07]\n            [-1.381e-05  7.067e-05 ...  6.387e-07  3.999e-04]]\n     nfev: 510\n     njev: 51', 'parameters': '[-3.391300379945393e-09, -5.976659799970454e-08, 3.1415927387084737, -4.593451958485803e-08, 9.42477799505803, 6.090275085878524e-09, 3.141592630310866, -1.1576776644065589e-08, -4.7057876896828284e-08]', 'optimization_trace': '[-4566.988546087752, -4566.988573834792, -4566.988549936847, -4566.988576844368, -4566.988546194811, -4566.988598529487, -4566.988562752874, -4566.988575757976, -4566.988565597738, -4566.988566362053, -9158.457112942793, -9158.457128954164, -9158.457101324586, -9158.45713457655, -9158.457112656139, -9158.457161550117, -9158.457088436293, -9158.4571302261, -9158.457085335922, -9158.457104752852, -15179.79572740835, -15179.795623247175, -15179.795735968786, -15179.795713604513, -15179.795727494413, -15179.795730117434, -15179.795665995638, -15179.795711127952, -15179.795655037042, -15179.795651116188, -22205.3852649297, -22205.385221726436, -22205.38520669043, -22205.38527050845, -22205.38526353086, -22205.385246586236, -22205.385253344768, -22205.385288276113, -22205.38525048694, -22205.38523493072, -13632.056662917224, -13632.056672762632, -13632.056799098924, -13632.056742646395, -13632.056666799948, -13632.056696009984, -13632.056620854382, -13632.056713768621, -13632.056629671568, -13632.05666509515, -22912.283543290403, -22912.28357263023, -22912.283498566037, -22912.283530838686, -22912.28354225713, -22912.283548927287, -22912.283530618268, -22912.283539350126, -22912.283528740485, -22912.283545261293, -23465.241110156072, -23465.241223954075, -23465.241114087083, -23465.24113681737, -23465.241110555457, -23465.241175392784, -23465.241067044313, -23465.241116240264, -23465.24106898931, -23465.241128827318, 22180.760357192055, 22180.76040579628, 22180.76036263799, 22180.76042750338, 22180.76037631929, 22180.760390132076, 22180.760330337314, 22180.760220375156, 22180.760654143218, 22180.76018089248, -23469.359792535524, -23469.359905073616, -23469.35979642311, -23469.35981984394, -23469.35979282824, -23469.359857799176, -23469.359749719373, -23469.359798183898, -23469.359750082964, -23469.35981510136, -23472.995001258125, -23472.99511426859, -23472.995004804037, -23472.995030159538, -23472.995001356776, -23472.995066923846, -23472.994960802847, -23472.995005312066, -23472.99495771837, -23472.99502136384, -23479.822098411296, -23479.8222113296, -23479.82210195259, -23479.8221277633, -23479.8220986 ...
# -35997.999999999935
# Result(need_flip=False, lsb_first=False, nbqbits=None, has_statevector=False, statevector=None, data=None, _value=None, raw_data=[Sample(_amplitude=None, probability=1.0, _state=84, err=0.0, intermediate_measurements=None, qregs=[DefaultRegister(length=9, start=0, msb=None, _subtype_metadata=None, key=None)])], qregs=[DefaultRegister(length=9, start=0, msb=None, _subtype_metadata=None, key=None)], error=None, value_data=None, error_data=None, meta_data={'nbshots': '10000'}, in_memory=None, _parameter_map=None, _values=None, values_data=None)
# |001010100> 1.0

# %%
probabilistic_heuristic(20)
# Out:
# {'|100010001>': 3, '|010001100>': 3, '|001010100>': 4, '|001100010>': 4, '|100001010>': 5, '|010100001>': 1}
# '|100001010>'

# %%
#for runtime = 200
states = []
plt.figure(figsize=(8, 6))
heights = []
for x, height in {'|100010001>': 40, '|010100001>': 29, '|001010100>': 38, '|010001100>': 24, '|001100010>': 26, '|100001010>': 43}.items() :
    states.append(x)
    heights.append(height)
plt.bar(states, heights)
plt.xlabel('States')
plt.ylabel('Number of occurance')
plt.title('Number of state occurance in Heuristic QAOA')
plt.show()

# %% [markdown]
# $$\textbf{4) Mixing the two approaches}$$

# %%
from qat.fermion.hamiltonians import SpinHamiltonian
from qat.fermion.trotterisation import make_trotterisation_routine
from qat.core import Term
H_cost = problem.get_observable()
terms = H_cost.terms
H_cost = SpinHamiltonian(nb_cities**2, terms, 1)
def custom_qaoa_ansatz(p):
    prog = Program()
    qbits = prog.qalloc(nb_cities**2)
    def create_mixer_hamiltonian(layer_nb):
        terms = []
        vars = [prog.new_var(float, f'beta{layer_nb},{j}') for j in range(nb_cities**2)]
        for i in range(nb_cities**2): 
            terms.append(Term(vars[i],"X", [i]))
        H_mixer = SpinHamiltonian(nb_cities**2, terms, 1)
        return(H_mixer)
    gamma = [ prog.new_var(float,f'gamma{i}') for i in range(p)   ]   
    for i in range(nb_cities**2):
        prog.apply(X, qbits[i])
    for i in range(0,p):
        H_mixer = create_mixer_hamiltonian(i)
        H2 =(gamma[i])*H_cost
        H1_rout = make_trotterisation_routine(H_mixer, 1,1)
        H2_rout = make_trotterisation_routine(H2, 1,1)
        prog.apply(H2_rout, qbits)
        prog.apply(H1_rout, qbits)
    circuit = prog.to_circ()
    job = circuit.to_job(observable=H_cost)
    return(job)

# %%
nb_layers = 5
ansatz = custom_qaoa_ansatz(nb_layers)
# We chose the BFGS method because it is often regarded as the fastest optimization method for problems like this
optimize = ScipyMinimizePlugin(
    method="BFGS", tol=1e-5, options={"maxiter": 1000}, x0 = [0.1]*(nb_layers*(nb_cities**2+1))
)  
# We create a stack : the optimizer will feed jobs to the bottom part (the qpu) and optimize their parameters
# We use the Broyden–Fletcher–Goldfarb–Shanno algorithm for the optimisation  as it usually works very well
qpu = CLinalg()
stack = (
    optimize | qpu
)  
result = stack.submit(ansatz)  # result
print("Energy : ", result.value)
# we get the optimal parameters from the result and bind the variables of the circuit
circuit = ansatz.circuit.bind_variables(
    result.parameter_map
) 
job = circuit.to_job(
    nbshots=1000
)  # a second job allowing us to know to what state the optimized parameters correspond 
qpu = CLinalg()
result = qpu.submit(job)  # result
# for each state in the result we print its probability
for sample in result:
    print("State %s amplitude %s" % (sample.state, sample.probability))
# we then have to choose the most probable one
# Out:
# Energy :  -91497.87454502487
# State |010100001> amplitude 1.0

# %%
energy_standard_QAOA=[]
energy_heuristic2=[]
runs_number=[]
for i in range(1,10):
    runs_number.append(i)
    energy1=run_qaoa(i)
    energy_standard_QAOA.append(energy1)
    ansatz = custom_qaoa_ansatz(nb_layers)
    optimize = ScipyMinimizePlugin(
    method="BFGS", tol=1e-5, options={"maxiter": 1000}, x0 = [0.1]*(nb_layers*(nb_cities**2+1))
    )  
    qpu = CLinalg()
    stack = (
    optimize | qpu
    )  
    result = stack.submit(ansatz) 
    energy2=result.value
    energy_heuristic2.append(energy2)

# %%
plt.plot(runs_number, energy_standard_QAOA, label='QAOA energy')
plt.plot(runs_number, energy_heuristic2, label='Heuristic energy')
plt.scatter(runs_number, energy_standard_QAOA)
plt.scatter(runs_number, energy_heuristic2)
plt.plot([0, 9], [-35998, -35998], "--", label = "optimal value")

plt.xlabel('number of layers for standard QAOA')
plt.ylabel('Energy (arbitrary unit)')
plt.title('Converged Energy as a function of the number of layer')
plt.legend(loc='best')
plt.grid()
# Show the plot
plt.show()
